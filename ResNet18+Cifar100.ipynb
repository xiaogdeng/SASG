# %% [markdown]
# # Result for **ResNet18+Cifar100**
# ### This notebook is for seed $42$. The results in the paper are the average of $5$ times with seeds in $[1, 19, 31, 42, 80]$

# %% [markdown]
# ## Libraries

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
from torchvision import datasets
import torchvision.transforms as transforms
from torch.utils.data import DataLoader, Subset

import os
import random
import numpy as np
import pandas as pd
import copy

import matplotlib
import matplotlib.pyplot as plt
from matplotlib.pyplot import MultipleLocator

# %% [markdown]
# ## Models

# %%
"""resnet in pytorch
[1] Kaiming He, Xiangyu Zhang, Shaoqing Ren, Jian Sun.
    Deep Residual Learning for Image Recognition
    https://arxiv.org/abs/1512.03385v1
"""
class BasicBlock(nn.Module):
    """Basic Block for resnet 18 and resnet 34
    """
    expansion = 1
    def __init__(self, in_channels, out_channels, stride=1):
        super(BasicBlock, self).__init__()

        self.residual_function = nn.Sequential(
            nn.Conv2d(in_channels, out_channels, kernel_size=3, stride=stride, padding=1, bias=False),
            nn.BatchNorm2d(out_channels),
            nn.ReLU(inplace=True),
            nn.Conv2d(out_channels, out_channels * BasicBlock.expansion, kernel_size=3, padding=1, bias=False),
            nn.BatchNorm2d(out_channels * BasicBlock.expansion)
        )
        self.shortcut = nn.Sequential()

        if stride != 1 or in_channels != BasicBlock.expansion * out_channels:
            self.shortcut = nn.Sequential(
                nn.Conv2d(in_channels, out_channels * BasicBlock.expansion, kernel_size=1, stride=stride, bias=False),
                nn.BatchNorm2d(out_channels * BasicBlock.expansion)
            )
    def forward(self, x):
        return nn.ReLU(inplace=True)(self.residual_function(x) + self.shortcut(x))


class BottleNeck(nn.Module):
    """Residual block for resnet over 50 layers
    """
    expansion = 4

    def __init__(self, in_channels, out_channels, stride=1):
        super(BottleNeck, self).__init__()
        self.residual_function = nn.Sequential(
            nn.Conv2d(in_channels, out_channels, kernel_size=1, bias=False),
            nn.BatchNorm2d(out_channels),
            nn.ReLU(inplace=True),
            nn.Conv2d(out_channels, out_channels, stride=stride, kernel_size=3, padding=1, bias=False),
            nn.BatchNorm2d(out_channels),
            nn.ReLU(inplace=True),
            nn.Conv2d(out_channels, out_channels * BottleNeck.expansion, kernel_size=1, bias=False),
            nn.BatchNorm2d(out_channels * BottleNeck.expansion),
        )
        self.shortcut = nn.Sequential()
        if stride != 1 or in_channels != out_channels * BottleNeck.expansion:
            self.shortcut = nn.Sequential(
                nn.Conv2d(in_channels, out_channels * BottleNeck.expansion, stride=stride, kernel_size=1, bias=False),
                nn.BatchNorm2d(out_channels * BottleNeck.expansion)
            )
    def forward(self, x):
        return nn.ReLU(inplace=True)(self.residual_function(x) + self.shortcut(x))


class ResNet(nn.Module):
    def __init__(self, block, num_block, num_classes=100):
        super(ResNet, self).__init__()
        self.in_channels = 64
        self.conv1 = nn.Sequential(
            nn.Conv2d(3, 64, kernel_size=3, padding=1, bias=False),
            nn.BatchNorm2d(64),
            nn.ReLU(inplace=True))
        self.conv2_x = self._make_layer(block, 64, num_block[0], 1)
        self.conv3_x = self._make_layer(block, 128, num_block[1], 2)
        self.conv4_x = self._make_layer(block, 256, num_block[2], 2)
        self.conv5_x = self._make_layer(block, 512, num_block[3], 2)
        self.avg_pool = nn.AdaptiveAvgPool2d((1, 1))
        self.fc = nn.Linear(512 * block.expansion, num_classes)
    def _make_layer(self, block, out_channels, num_blocks, stride):
        """make resnet layers(by layer i didnt mean this 'layer' was the
        same as a neuron netowork layer, ex. conv layer), one layer may
        contain more than one residual block
        Args:
            block: block type, basic block or bottle neck block
            out_channels: output depth channel number of this layer
            num_blocks: how many blocks per layer
            stride: the stride of the first block of this layer
        Return:
            return a resnet layer
        """
        strides = [stride] + [1] * (num_blocks - 1)
        layers = []
        for stride in strides:
            layers.append(block(self.in_channels, out_channels, stride))
            self.in_channels = out_channels * block.expansion
        return nn.Sequential(*layers)
    def forward(self, x):
        output = self.conv1(x)
        output = self.conv2_x(output)
        output = self.conv3_x(output)
        output = self.conv4_x(output)
        output = self.conv5_x(output)
        output = self.avg_pool(output)
        output = output.view(output.size(0), -1)
        output = self.fc(output)
        return output


def resnet18():
    return ResNet(BasicBlock, [2, 2, 2, 2])


def resnet18_copy():
    return ResNet(BasicBlock, [2, 2, 2, 2])

# %% [markdown]
# ## Prepare data

# %%
def create_loaders(dataset_name, n_workers, batch_size):
    train_data, test_data = load_data(dataset_name)
    train_loader_workers = dict()
    n = len(train_data)
    
    # preparing iterators for workers
    indices = np.arange(n)
    np.random.shuffle(indices)
    a = np.int(np.floor(n / n_workers))
    top_ind = a * n_workers
    seq = range(a, top_ind, a)
    split = np.split(indices[:top_ind], seq)
    b = 0
    for ind in split:
        train_loader_workers[b] = DataLoader(Subset(train_data, ind), batch_size=batch_size, shuffle=True)
        b = b + 1
    test_loader = DataLoader(test_data, batch_size=batch_size, shuffle=False)

    return train_loader_workers, test_loader


def load_data(dataset_name):
    if dataset_name == 'mnist':
        transform = transforms.Compose([
            transforms.ToTensor(),
            transforms.Normalize((0.1307,), (0.3081,))
        ])
        train_data = datasets.MNIST(root='./data', train=True,
                                    download=True, transform=transform)
        test_data = datasets.MNIST(root='./data', train=False,
                                   download=True, transform=transform)

    elif dataset_name == 'cifar10':
        transform_train = transforms.Compose([
            transforms.RandomCrop(32, padding=4),
            transforms.RandomHorizontalFlip(),
            transforms.ToTensor(),
            transforms.Normalize((0.4914, 0.4822, 0.4465), (0.2023, 0.1994, 0.2010)),
        ])
        transform_test = transforms.Compose([
            transforms.ToTensor(),
            transforms.Normalize((0.4914, 0.4822, 0.4465), (0.2023, 0.1994, 0.2010)),
        ])
        train_data = datasets.CIFAR10(root='./data', train=True,
                                      download=True, transform=transform_train)
        test_data = datasets.CIFAR10(root='./data', train=False,
                                     download=True, transform=transform_test)

    elif dataset_name == 'cifar100':
        transform_train = transforms.Compose([
            transforms.RandomCrop(32, padding=4),
            transforms.RandomHorizontalFlip(),
            transforms.RandomRotation(15),
            transforms.ToTensor(),
            transforms.Normalize(mean=[0.5070751592371323, 0.48654887331495095, 0.4409178433670343],
                                 std=[0.5070751592371323, 0.48654887331495095, 0.4409178433670343])
        ])
        transform_test = transforms.Compose([
            transforms.ToTensor(),
            transforms.Normalize(mean=[0.5070751592371323, 0.48654887331495095, 0.4409178433670343],
                                 std=[0.5070751592371323, 0.48654887331495095, 0.4409178433670343])
        ])
        train_data = datasets.CIFAR100(root='./data', train=True,
                                       download=True, transform=transform_train)
        test_data = datasets.CIFAR100(root='./data', train=False,
                                      download=True, transform=transform_test)

    else:
        raise ValueError(dataset_name + ' is not known.')

    return train_data, test_data

# %% [markdown]
# ## Parameter and Setup

# %%
# Hyperparameters
RANDOM_SEED = 42
lr = 0.01
BATCH_SIZE = 10
NUM_EPOCHS = 50
NUM_WORKERS = 10
D = 10  # compute thread
h = 0.01  # sparse level 99%

if not os.path.exists('result'):
    os.mkdir('result')
DEVICE = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print("Using device: ", DEVICE)
# Out:
# Using device:  cuda

# %% [markdown]
# ## Functions

# %%
def seed_torch(seed):
    random.seed(seed)
    os.environ['PYTHONHASHSEED'] = str(seed)
    np.random.seed(seed)
    torch.manual_seed(seed)
    torch.cuda.manual_seed(seed)
    torch.cuda.manual_seed_all(seed)  # if you are using multi-GPU.
    torch.backends.cudnn.benchmark = False
    torch.backends.cudnn.deterministic = True
    
    
def evaluate_accuracy(model, data_iter, device):
    correct_1 = 0.0
    correct_5 = 0.0

    for image, label in data_iter:
        image, label = image.to(device), label.to(device)
        output = model(image)

        _, pred = output.topk(5, 1, largest=True, sorted=True)
        label = label.view(label.size(0), -1).expand_as(pred)
        correct = pred.eq(label).float()

        # compute top 5
        correct_5 += correct[:, :5].sum().item()
        # compute top1
        correct_1 += correct[:, :1].sum().item()

    accuracy_1 = 100. * correct_1 / len(data_iter.dataset)
    accuracy_5 = 100. * correct_5 / len(data_iter.dataset)
    return accuracy_1, accuracy_5


# Top_k sparse
def prep_grad(x):
    x_flat = torch.unsqueeze(x, 0).flatten()
    dim = x.shape
    d = x_flat.shape[0]
    return x_flat, dim, d


def top_k_opt(x, h):
    """
    :param x: vector to sparsify
    :param h: density
    :return: compressed vector
    """
    x, dim, d = prep_grad(x)
    # number of coordinates kept
    r = int(np.maximum(1, np.floor(d * h)))
    # positions of top_k coordinates
    _, ind = torch.topk(torch.abs(x), r)
    mask = torch.zeros_like(x)
    mask[ind] = 1
    t = mask * x
    t = t.reshape(dim)
    return t


def compt(old, new):
    result = 0.0
    for i in range(len(old)):
        result += ((old[i].view(-1) - new[i].view(-1)) ** 2).sum().item()
    return result


def adjust_lr(epoch_input):
    lr_ad, lr_th = 0.01, 0.01
    if epoch_input >= 30:
        lr_ad = 0.001
    if epoch_input > 30:
        lr_th = 0.001
    return lr_ad, lr_th

# %% [markdown]
# # SASG

# %%
print("SASG  lr:"+str(lr)+"--h:"+str(h)+"--epoch:"+str(NUM_EPOCHS)+"--worker:"+str(NUM_WORKERS))
seed_torch(RANDOM_SEED)
model = resnet18()
model.to(DEVICE)
model_copy = resnet18_copy()
model_copy.to(DEVICE)
loss = nn.CrossEntropyLoss()  # 损失函数

# prepare data
dataset_name = 'cifar100'
train_loader_workers, test_loader = create_loaders(dataset_name, NUM_WORKERS, BATCH_SIZE)

NUM_PARAS = sum([1 for param in model.parameters()])
print("Number_parameter:", NUM_PARAS)
total_params = sum(p.numel() for p in model.parameters() if p.requires_grad)
print("Element_parameter:", total_params)
total_params_sparse = 0
for p in model.parameters():
    x, dim, d = prep_grad(p)
    r = int(np.maximum(1, np.floor(d * h)))
    total_params_sparse += r
print("Element_parameter_sparse:", total_params_sparse)

state_dict = [0 for col in range(NUM_WORKERS)]
grad_worker = [[0 for col in range(NUM_PARAS)] for row in range(NUM_WORKERS)]
error_worker = [[0 for col in range(NUM_PARAS)] for row in range(NUM_WORKERS)]
grad_old = [0 for col in range(NUM_PARAS)]
grad_new = [0 for col in range(NUM_PARAS)]
para_store = [0 for col in range(NUM_PARAS)]
tau = [0 for col in range(NUM_WORKERS)]
para_list = []
Skip_epoch = []
Loss_epoch = []
train_acc_epoch = []
test_acc_epoch = []

Skip_iter = []
Loss_iter = []
train_acc_iter = []
test_acc_iter = []

iter_num = 0
skip_iter = 0
flag_acc = False

for epoch in range(NUM_EPOCHS):
    train_l_sum, train_acc_sum, num = 0.0, 0.0, 0
    train_loader_iter = [iter(train_loader_workers[w]) for w in range(NUM_WORKERS)]
    iter_steps = len(train_loader_workers[0])
    skip_num = [[0 for col in range(iter_steps)] for row in range(NUM_EPOCHS)]

    # adjust learning_rate
    lr, lr_thead = adjust_lr(epoch)
    print("EPOCH: ", epoch + 1, "learning rate: ", lr)

    for batch_idx in range(iter_steps):
        model.train()
        model_copy.train()
        grad_agg = [0 for col in range(NUM_PARAS)]
        skip_idx = 0
        if (epoch * iter_steps + batch_idx) < D:
            for w_id in range(NUM_WORKERS):
                images, labels = next(train_loader_iter[w_id])
                images, labels = images.to(DEVICE), labels.to(DEVICE)
                y_hat = model(images)
                Loss = loss(y_hat, labels)
                Loss.backward()
                with torch.no_grad():
                    p_id = 0
                    for p in model.parameters():
                        g = lr * p.grad.data.clone().detach() + error_worker[w_id][p_id]
                        Tk_sparse = top_k_opt(g, h)
                        grad_agg[p_id] += Tk_sparse
                        error_worker[w_id][p_id] = g - Tk_sparse
                        grad_worker[w_id][p_id] = Tk_sparse
                        p_id += 1
                        p.grad.zero_()

                state_dict[w_id] = copy.deepcopy(model.state_dict())
                train_l_sum += Loss.item()
                train_acc_sum += (y_hat.argmax(dim=1) == labels).sum().item()
                num += labels.shape[0]
        else:
            thread = 0.0
            with torch.no_grad():
                for i in range(len(para_list) - 1):
                    thread += compt(para_list[i], para_list[i + 1])
            thread = thread / (lr_thead * (NUM_WORKERS ** 2))
            for w_id in range(NUM_WORKERS):
                images, labels = next(train_loader_iter[w_id])
                images, labels = images.to(DEVICE), labels.to(DEVICE)
                model_copy.load_state_dict(state_dict[w_id])
                y_copy = model_copy(images)
                Loss_copy = loss(y_copy, labels)
                Loss_copy.backward()
                y_hat = model(images)
                Loss = loss(y_hat, labels)
                Loss.backward()
                with torch.no_grad():
                    p_old_id = 0
                    for p_old in model_copy.parameters():
                        grad_old[p_old_id] = p_old.grad.data.clone().detach()
                        p_old_id += 1
                        p_old.grad.zero_()
                    p_id = 0
                    for p in model.parameters():
                        grad_new[p_id] = p.grad.data.clone().detach()
                        p_id += 1
                    if compt(grad_old, grad_new) > 1.25 * thread or tau[w_id] > D:
                        tau[w_id] = 1
                        p_id = 0
                        for p in model.parameters():
                            g = lr * p.grad.data.clone().detach() + error_worker[w_id][p_id]
                            Tk_sparse = top_k_opt(g, h)
                            grad_agg[p_id] += Tk_sparse
                            error_worker[w_id][p_id] = g - Tk_sparse
                            grad_worker[w_id][p_id] = Tk_sparse
                            p_id += 1
                            p.grad.zero_()
                        state_dict[w_id] = copy.deepcopy(model.state_dict())
                    else:
                        skip_idx += 1
                        tau[w_id] += 1
                        p_id = 0
                        for p in model.parameters():
                            grad_agg[p_id] += grad_worker[w_id][p_id]
                            p_id += 1
                            p.grad.zero_()
                train_l_sum += Loss.item()
                train_acc_sum += (y_hat.argmax(dim=1) == labels).sum().item()
                num += labels.shape[0]
        skip_num[epoch][batch_idx] = skip_idx
        with torch.no_grad():
            p_id = 0
            for p in model.parameters():
                p.data.add_(grad_agg[p_id], alpha=-1)
                para_store[p_id] = p.data.clone().detach()
                p_id += 1
                p.grad.zero_()
            para_list.insert(0, para_store.copy())
            if len(para_list) > D:
                para_list.pop()
        # LOGGING
        if not (batch_idx + 1) % 100:
            print('Epoch: %03d/%03d | Batch %04d/%04d | Cost: %.4f'
                % (epoch + 1, NUM_EPOCHS, batch_idx + 1, len(train_loader_workers[0]), Loss.item()))
        iter_num += 1
        skip_iter += skip_idx
        if not iter_num % 100:
            model.eval()
            with torch.no_grad():
                _, test_acc_it = evaluate_accuracy(model, test_loader, DEVICE)
                Skip_iter.append(skip_iter)
                Loss_iter.append(train_l_sum / (num / BATCH_SIZE))
                train_acc_iter.append(train_acc_sum / num * 100)
                test_acc_iter.append(test_acc_it)
            if test_acc_it > 92.0 and not flag_acc:
                flag_acc = True
                print("*" * 100)
                print("Iter_num:", iter_num, "Test_acc", test_acc_it, "Skip_round:", skip_iter, "Comm_round:", iter_num * 10 - skip_iter)  # 10 workers
                print("*" * 100)
    model.eval()
    with torch.no_grad():
        test_acc_1, test_acc_5 = evaluate_accuracy(model, test_loader, DEVICE)
        Skip_epoch.append(sum(skip_num[epoch]))
        Loss_epoch.append(train_l_sum / (num / BATCH_SIZE))
        train_acc_epoch.append(train_acc_sum / num * 100)
        test_acc_epoch.append(test_acc_5)
    print('epoch %d, skip_num %d, loss %.4f, train acc %.3f%%, top_1 test acc %.3f%%, top_5 test acc %.3f%%'
        % (epoch + 1, Skip_epoch[epoch], train_l_sum / (num / BATCH_SIZE), train_acc_sum / num * 100, test_acc_1, test_acc_5))

print('Finished.')

list_write = []
list_write.append(Skip_epoch)
list_write.append(Loss_epoch)
list_write.append(train_acc_epoch)
list_write.append(test_acc_epoch)
name = ['Skip', 'Loss', 'train-acc', 'test-acc']
test = pd.DataFrame(index=name, data=list_write).T
test.to_csv("./result/"+"SASG-res-cifar100.csv", encoding='gbk')


list_write_iter = []
list_write_iter.append(Skip_iter)
list_write_iter.append(Loss_iter)
list_write_iter.append(train_acc_iter)
list_write_iter.append(test_acc_iter)
name_iter = ['Skip', 'Loss', 'train-acc', 'test-acc']
test = pd.DataFrame(index=name_iter, data=list_write_iter).T
test.to_csv("./result/"+"SASG-res-cifar100-iter.csv", encoding='gbk')
# Out:
# SASG  lr:0.01--h:0.01--epoch:50--worker:10
# Files already downloaded and verified
# Files already downloaded and verified
# C:\Users\DxiaoG\AppData\Local\Temp\Mxt230\tmp\ipykernel_18272\1940885620.py:9: DeprecationWarning: `np.int` is a deprecated alias for the builtin `int`. To silence this warning, use `int` by itself. Doing this will not modify any behavior and is safe. When replacing `np.int`, you may wish to use e.g. `np.int64` or `np.int32` to specify the precision. If you wish to review your current use, check the release note link for additional information.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   a = np.int(np.floor(n / n_workers))
# Number_parameter: 62
# Element_parameter: 11220132
# Element_parameter_sparse: 112184
# EPOCH:  1 learning rate:  0.01
# Epoch: 001/050 | Batch 0100/0500 | Cost: 4.5178
# Epoch: 001/050 | Batch 0200/0500 | Cost: 3.8783
# Epoch: 001/050 | Batch 0300/0500 | Cost: 3.1982
# Epoch: 001/050 | Batch 0400/0500 | Cost: 3.1055
# Epoch: 001/050 | Batch 0500/0500 | Cost: 2.4628
# epoch 1, skip_num 0, loss 3.7421, train acc 12.866%, top_1 test acc 24.220%, top_5 test acc 54.290%
# EPOCH:  2 learning rate:  0.01
# Epoch: 002/050 | Batch 0100/0500 | Cost: 2.9819
# Epoch: 002/050 | Batch 0200/0500 | Cost: 2.7393
# Epoch: 002/050 | Batch 0300/0500 | Cost: 2.5725
# Epoch: 002/050 | Batch 0400/0500 | Cost: 3.1374
# Epoch: 002/050 | Batch 0500/0500 | Cost: 3.0704
# epoch 2, skip_num 0, loss 2.9813, train acc 25.596%, top_1 test acc 34.890%, top_5 test acc 66.790%
# EPOCH:  3 learning rate:  0.01
# Epoch: 003/050 | Batch 0100/0500 | Cost: 2.2989
# Epoch: 003/050 | Batch 0200/0500 | Cost: 1.7592
# Epoch: 003/050 | Batch 0300/0500 | Cost: 2.2360
# Epoch: 003/050 | Batch 0400/0500 | Cost: 2.2081
# Epoch: 003/050 | Batch 0500/0500 | Cost: 2.8839
# epoch 3, skip_num 0, loss 2.5491, train acc 34.240%, top_1 test acc 42.560%, top_5 test acc 74.230%
# EPOCH:  4 learning rate:  0.01
# Epoch: 004/050 | Batch 0100/0500 | Cost: 2.0423
# Epoch: 004/050 | Batch 0200/0500 | Cost: 2.1136
# Epoch: 004/050 | Batch 0300/0500 | Cost: 1.8235
# Epoch: 004/050 | Batch 0400/0500 | Cost: 2.2334
# Epoch: 004/050 | Batch 0500/0500 | Cost: 2.5003
# epoch 4, skip_num 1, loss 2.2646, train acc 40.426%, top_1 test acc 47.170%, top_5 test acc 77.480%
# EPOCH:  5 learning rate:  0.01
# Epoch: 005/050 | Batch 0100/0500 | Cost: 1.5515
# Epoch: 005/050 | Batch 0200/0500 | Cost: 2.0487
# Epoch: 005/050 | Batch 0300/0500 | Cost: 2.4848
# Epoch: 005/050 | Batch 0400/0500 | Cost: 2.4490
# Epoch: 005/050 | Batch 0500/0500 | Cost: 1.8664
# epoch 5, skip_num 8, loss 2.0568, train acc 44.994%, top_1 test acc 50.820%, top_5 test acc 81.340%
# EPOCH:  6 learning rate:  0.01
# Epoch: 006/050 | Batch 0100/0500 | Cost: 1.8260
# Epoch: 006/050 | Batch 0200/0500 | Cost: 2.3705
# Epoch: 006/050 | Batch 0300/0500 | Cost: 1.1999
# Epoch: 006/050 | Batch 0400/0500 | Cost: 2.0069
# Epoch: 006/050 | Batch 0500/0500 | Cost: 3.1225
# epoch 6, skip_num 25, loss 1.8882, train acc 48.818%, top_1 test acc 54.420%, top_5 test acc 82.980%
# EPOCH:  7 learning rate:  0.01
# Epoch: 007/050 | Batch 0100/0500 | Cost: 2.0334
# Epoch: 007/050 | Batch 0200/0500 | Cost: 1.2574
# Epoch: 007/050 | Batch 0300/0500 | Cost: 1.8279
# Epoch: 007/050 | Batch 0400/0500 | Cost: 2.9022
# Epoch: 007/050 | Batch 0500/0500 | Cost: 2.9196
# epoch 7, skip_num 55, loss 1.7680, train acc 51.762%, top_1 test acc 56.220%, top_5 test acc 84.690%
# EPOCH:  8 learning rate:  0.01
# Epoch: 008/050 | Batch 0100/0500 | Cost: 2.9184
# Epoch: 008/050 | Batch 0200/0500 | Cost: 0.8799
# Epoch: 008/050 | Batch 0300/0500 | Cost: 1.5319
# Epoch: 008/050 | Batch 0400/0500 | Cost: 1.5253
# Epoch: 008/050 | Batch 0500/0500 | Cost: 1.2904
# epoch 8, skip_num 80, loss 1.6598, train acc 54.152%, top_1 test acc 59.000%, top_5 test acc 85.770%
# EPOCH:  9 learning rate:  0.01
# Epoch: 009/050 | Batch 0100/0500 | Cost: 1.8610
# Epoch: 009/050 | Batch 0200/0500 | Cost: 3.2054
# Epoch: 009/050 | Batch 0300/0500 | Cost: 1.2189
# Epoch: 009/050 | Batch 0400/0500 | Cost: 1.4612
# Epoch: 009/050 | Batch 0500/0500 | Cost: 1.7314
# epoch 9, skip_num 130, loss 1.5632, train acc 56.732%, top_1 test acc 58.320%, top_5 test acc 85.960%
# EPOCH:  10 learning rate:  0.01
# Epoch: 010/050 | Batch 0100/0500 | Cost: 1.2010
# Epoch: 010/050 | Batch 0200/0500 | Cost: 0.8081
# Epoch: 010/050 | Batch 0300/0500 | Cost: 1.9310
# Epoch: 010/050 | Batch 0400/0500 | Cost: 1.0057
# Epoch: 010/050 | Batch 0500/0500 | Cost: 1.4514
# epoch 10, skip_num 159, loss 1.4905, train acc 58.192%, top_1 test acc 59.800%, top_5 test acc 86.840%
# EPOCH:  11 learning rate:  0.01
# Epoch: 011/050 | Batch 0100/0500 | Cost: 0.9677
# Epoch: 011/050 | Batch 0200/0500 | Cost: 0.8886
# Epoch: 011/050 | Batch 0300/0500 | Cost: 1.2420
# Epoch: 011/050 | Batch 0400/0500 | Cost: 2.3992
# Epoch: 011/050 | Batch 0500/0500 | Cost: 0.7535
# epoch 11, skip_num 222, loss 1.4151, train acc 60.026%, top_1 test acc 62.460%, top_5 test acc 88.010%
# EPOCH:  12 learning rate:  0.01
# Epoch: 012/050 | Batch 0100/0500 | Cost: 1.4215
# Epoch: 012/050 | Batch 0200/0500 | Cost: 1.5929
# Epoch: 012/050 | Batch 0300/0500 | Cost: 2.1423
# Epoch: 012/050 | Batch 0400/0500 | Cost: 0.8653
# Epoch: 012/050 | Batch 0500/0500 | Cost: 0.1921
# epoch 12, skip_num 284, loss 1.3507, train acc 61.886%, top_1 test acc 62.070%, top_5 test acc 87.700%
# EPOCH:  13 learning rate:  0.01
# Epoch: 013/050 | Batch 0100/0500 | Cost: 1.5530
# Epoch: 013/050 | Batch 0200/0500 | Cost: 0.7512
# Epoch: 013/050 | Batch 0300/0500 | Cost: 1.6041
# Epoch: 013/050 | Batch 0400/0500 | Cost: 1.2178
# Epoch: 013/050 | Batch 0500/0500 | Cost: 1.3520
# epoch 13, skip_num 314, loss 1.2998, train acc 62.670%, top_1 test acc 63.010%, top_5 test acc 88.430%
# EPOCH:  14 learning rate:  0.01
# Epoch: 014/050 | Batch 0100/0500 | Cost: 1.7791
# Epoch: 014/050 | Batch 0200/0500 | Cost: 0.8045
# Epoch: 014/050 | Batch 0300/0500 | Cost: 1.6596
# Epoch: 014/050 | Batch 0400/0500 | Cost: 1.3533
# Epoch: 014/050 | Batch 0500/0500 | Cost: 1.2727
# epoch 14, skip_num 369, loss 1.2506, train acc 64.104%, top_1 test acc 63.470%, top_5 test acc 88.820%
# EPOCH:  15 learning rate:  0.01
# Epoch: 015/050 | Batch 0100/0500 | Cost: 1.0508
# Epoch: 015/050 | Batch 0200/0500 | Cost: 1.8396
# Epoch: 015/050 | Batch 0300/0500 | Cost: 1.7507
# Epoch: 015/050 | Batch 0400/0500 | Cost: 1.7565
# Epoch: 015/050 | Batch 0500/0500 | Cost: 0.6030
# epoch 15, skip_num 490, loss 1.2036, train acc 65.424%, top_1 test acc 64.910%, top_5 test acc 89.360%
# EPOCH:  16 learning rate:  0.01
# Epoch: 016/050 | Batch 0100/0500 | Cost: 1.2429
# Epoch: 016/050 | Batch 0200/0500 | Cost: 1.9017
# Epoch: 016/050 | Batch 0300/0500 | Cost: 0.7104
# Epoch: 016/050 | Batch 0400/0500 | Cost: 1.6078
# Epoch: 016/050 | Batch 0500/0500 | Cost: 1.7223
# epoch 16, skip_num 547, loss 1.1537, train acc 66.708%, top_1 test acc 64.990%, top_5 test acc 89.090%
# EPOCH:  17 learning rate:  0.01
# Epoch: 017/050 | Batch 0100/0500 | Cost: 0.6702
# Epoch: 017/050 | Batch 0200/0500 | Cost: 0.9601
# Epoch: 017/050 | Batch 0300/0500 | Cost: 1.2891
# Epoch: 017/050 | Batch 0400/0500 | Cost: 0.8979
# Epoch: 017/050 | Batch 0500/0500 | Cost: 0.8899
# epoch 17, skip_num 590, loss 1.1048, train acc 67.860%, top_1 test acc 65.580%, top_5 test acc 89.830%
# EPOCH:  18 learning rate:  0.01
# Epoch: 018/050 | Batch 0100/0500 | Cost: 0.8032
# Epoch: 018/050 | Batch 0200/0500 | Cost: 1.5736
# Epoch: 018/050 | Batch 0300/0500 | Cost: 0.6434
# Epoch: 018/050 | Batch 0400/0500 | Cost: 1.2213
# Epoch: 018/050 | Batch 0500/0500 | Cost: 1.6136
# epoch 18, skip_num 653, loss 1.0786, train acc 68.576%, top_1 test acc 64.710%, top_5 test acc 89.190%
# EPOCH:  19 learning rate:  0.01
# Epoch: 019/050 | Batch 0100/0500 | Cost: 1.2491
# Epoch: 019/050 | Batch 0200/0500 | Cost: 1.2818
# Epoch: 019/050 | Batch 0300/0500 | Cost: 1.0955
# Epoch: 019/050 | Batch 0400/0500 | Cost: 0.7965
# Epoch: 019/050 | Batch 0500/0500 | Cost: 0.6286
# epoch 19, skip_num 695, loss 1.0375, train acc 69.458%, top_1 test acc 66.090%, top_5 test acc 90.090%
# EPOCH:  20 learning rate:  0.01
# Epoch: 020/050 | Batch 0100/0500 | Cost: 0.6062
# Epoch: 020/050 | Batch 0200/0500 | Cost: 0.2908
# Epoch: 020/050 | Batch 0300/0500 | Cost: 0.7269
# Epoch: 020/050 | Batch 0400/0500 | Cost: 0.9186
# Epoch: 020/050 | Batch 0500/0500 | Cost: 1.3709
# epoch 20, skip_num 763, loss 1.0003, train acc 70.456%, top_1 test acc 66.710%, top_5 test acc 90.020%
# EPOCH:  21 learning rate:  0.01
# Epoch: 021/050 | Batch 0100/0500 | Cost: 0.3569
# Epoch: 021/050 | Batch 0200/0500 | Cost: 1.1075
# Epoch: 021/050 | Batch 0300/0500 | Cost: 1.0142
# Epoch: 021/050 | Batch 0400/0500 | Cost: 1.2430
# Epoch: 021/050 | Batch 0500/0500 | Cost: 0.6330
# epoch 21, skip_num 831, loss 0.9692, train acc 71.380%, top_1 test acc 67.630%, top_5 test acc 90.600%
# EPOCH:  22 learning rate:  0.01
# Epoch: 022/050 | Batch 0100/0500 | Cost: 0.4638
# Epoch: 022/050 | Batch 0200/0500 | Cost: 0.8958
# Epoch: 022/050 | Batch 0300/0500 | Cost: 0.9853
# Epoch: 022/050 | Batch 0400/0500 | Cost: 1.6236
# Epoch: 022/050 | Batch 0500/0500 | Cost: 1.3351
# epoch 22, skip_num 877, loss 0.9376, train acc 72.300%, top_1 test acc 67.500%, top_5 test acc 90.820%
# EPOCH:  23 learning rate:  0.01
# Epoch: 023/050 | Batch 0100/0500 | Cost: 1.0203
# Epoch: 023/050 | Batch 0200/0500 | Cost: 0.7414
# Epoch: 023/050 | Batch 0300/0500 | Cost: 0.5166
# Epoch: 023/050 | Batch 0400/0500 | Cost: 0.4162
# Epoch: 023/050 | Batch 0500/0500 | Cost: 1.0485
# epoch 23, skip_num 911, loss 0.9034, train acc 72.912%, top_1 test acc 66.650%, top_5 test acc 90.410%
# EPOCH:  24 learning rate:  0.01
# Epoch: 024/050 | Batch 0100/0500 | Cost: 0.3031
# Epoch: 024/050 | Batch 0200/0500 | Cost: 0.3934
# Epoch: 024/050 | Batch 0300/0500 | Cost: 0.6977
# Epoch: 024/050 | Batch 0400/0500 | Cost: 1.1546
# Epoch: 024/050 | Batch 0500/0500 | Cost: 0.6221
# epoch 24, skip_num 995, loss 0.8817, train acc 73.746%, top_1 test acc 67.710%, top_5 test acc 90.630%
# EPOCH:  25 learning rate:  0.01
# Epoch: 025/050 | Batch 0100/0500 | Cost: 1.3175
# Epoch: 025/050 | Batch 0200/0500 | Cost: 0.5686
# Epoch: 025/050 | Batch 0300/0500 | Cost: 1.4409
# Epoch: 025/050 | Batch 0400/0500 | Cost: 1.0262
# Epoch: 025/050 | Batch 0500/0500 | Cost: 0.7230
# epoch 25, skip_num 1022, loss 0.8606, train acc 74.094%, top_1 test acc 67.180%, top_5 test acc 90.570%
# EPOCH:  26 learning rate:  0.01
# Epoch: 026/050 | Batch 0100/0500 | Cost: 0.8998
# Epoch: 026/050 | Batch 0200/0500 | Cost: 0.4867
# Epoch: 026/050 | Batch 0300/0500 | Cost: 0.3657
# Epoch: 026/050 | Batch 0400/0500 | Cost: 1.0617
# Epoch: 026/050 | Batch 0500/0500 | Cost: 1.0686
# epoch 26, skip_num 1115, loss 0.8322, train acc 74.886%, top_1 test acc 68.320%, top_5 test acc 90.860%
# EPOCH:  27 learning rate:  0.01
# Epoch: 027/050 | Batch 0100/0500 | Cost: 0.1920
# Epoch: 027/050 | Batch 0200/0500 | Cost: 0.4361
# Epoch: 027/050 | Batch 0300/0500 | Cost: 0.9894
# Epoch: 027/050 | Batch 0400/0500 | Cost: 0.2947
# Epoch: 027/050 | Batch 0500/0500 | Cost: 0.7039
# epoch 27, skip_num 1158, loss 0.8086, train acc 75.424%, top_1 test acc 67.970%, top_5 test acc 90.370%
# EPOCH:  28 learning rate:  0.01
# Epoch: 028/050 | Batch 0100/0500 | Cost: 0.5013
# Epoch: 028/050 | Batch 0200/0500 | Cost: 1.0140
# Epoch: 028/050 | Batch 0300/0500 | Cost: 0.8051
# Epoch: 028/050 | Batch 0400/0500 | Cost: 0.7640
# Epoch: 028/050 | Batch 0500/0500 | Cost: 1.0595
# epoch 28, skip_num 1190, loss 0.7820, train acc 76.258%, top_1 test acc 67.980%, top_5 test acc 90.540%
# EPOCH:  29 learning rate:  0.01
# Epoch: 029/050 | Batch 0100/0500 | Cost: 0.9768
# Epoch: 029/050 | Batch 0200/0500 | Cost: 0.6337
# Epoch: 029/050 | Batch 0300/0500 | Cost: 0.6706
# Epoch: 029/050 | Batch 0400/0500 | Cost: 1.0372
# Epoch: 029/050 | Batch 0500/0500 | Cost: 1.4154
# epoch 29, skip_num 1265, loss 0.7575, train acc 77.084%, top_1 test acc 68.820%, top_5 test acc 91.110%
# EPOCH:  30 learning rate:  0.01
# Epoch: 030/050 | Batch 0100/0500 | Cost: 0.5756
# Epoch: 030/050 | Batch 0200/0500 | Cost: 0.7807
# Epoch: 030/050 | Batch 0300/0500 | Cost: 0.9030
# Epoch: 030/050 | Batch 0400/0500 | Cost: 0.8235
# Epoch: 030/050 | Batch 0500/0500 | Cost: 0.4389
# epoch 30, skip_num 1308, loss 0.7392, train acc 77.614%, top_1 test acc 68.080%, top_5 test acc 90.970%
# EPOCH:  31 learning rate:  0.001
# Epoch: 031/050 | Batch 0100/0500 | Cost: 0.8673
# Epoch: 031/050 | Batch 0200/0500 | Cost: 0.4454
# Epoch: 031/050 | Batch 0300/0500 | Cost: 0.3358
# Epoch: 031/050 | Batch 0400/0500 | Cost: 0.8518
# ****************************************************************************************************
# Iter_num: 15400 Test_acc 92.12 Skip_round: 16456 Comm_round: 137544
# ****************************************************************************************************
# Epoch: 031/050 | Batch 0500/0500 | Cost: 0.7369
# epoch 31, skip_num 415, loss 0.6332, train acc 80.806%, top_1 test acc 70.930%, top_5 test acc 92.210%
# EPOCH:  32 learning rate:  0.001
# Epoch: 032/050 | Batch 0100/0500 | Cost: 0.6025
# Epoch: 032/050 | Batch 0200/0500 | Cost: 0.9294
# Epoch: 032/050 | Batch 0300/0500 | Cost: 1.4837
# Epoch: 032/050 | Batch 0400/0500 | Cost: 0.6126
# Epoch: 032/050 | Batch 0500/0500 | Cost: 0.3541
# epoch 32, skip_num 2288, loss 0.5150, train acc 84.698%, top_1 test acc 71.520%, top_5 test acc 92.480%
# EPOCH:  33 learning rate:  0.001
# Epoch: 033/050 | Batch 0100/0500 | Cost: 0.8665
# Epoch: 033/050 | Batch 0200/0500 | Cost: 0.7494
# Epoch: 033/050 | Batch 0300/0500 | Cost: 1.0764
# Epoch: 033/050 | Batch 0400/0500 | Cost: 0.1816
# Epoch: 033/050 | Batch 0500/0500 | Cost: 0.3840
# epoch 33, skip_num 2384, loss 0.4857, train acc 85.416%, top_1 test acc 71.810%, top_5 test acc 92.580%
# EPOCH:  34 learning rate:  0.001
# Epoch: 034/050 | Batch 0100/0500 | Cost: 0.8854
# Epoch: 034/050 | Batch 0200/0500 | Cost: 0.2576
# Epoch: 034/050 | Batch 0300/0500 | Cost: 0.9884
# Epoch: 034/050 | Batch 0400/0500 | Cost: 0.6351
# Epoch: 034/050 | Batch 0500/0500 | Cost: 0.5494
# epoch 34, skip_num 2317, loss 0.4687, train acc 86.072%, top_1 test acc 72.010%, top_5 test acc 92.670%
# EPOCH:  35 learning rate:  0.001
# Epoch: 035/050 | Batch 0100/0500 | Cost: 0.3606
# Epoch: 035/050 | Batch 0200/0500 | Cost: 0.1032
# Epoch: 035/050 | Batch 0300/0500 | Cost: 0.2933
# Epoch: 035/050 | Batch 0400/0500 | Cost: 0.8281
# Epoch: 035/050 | Batch 0500/0500 | Cost: 0.7572
# epoch 35, skip_num 2348, loss 0.4503, train acc 86.540%, top_1 test acc 72.140%, top_5 test acc 92.670%
# EPOCH:  36 learning rate:  0.001
# Epoch: 036/050 | Batch 0100/0500 | Cost: 0.6913
# Epoch: 036/050 | Batch 0200/0500 | Cost: 0.4893
# Epoch: 036/050 | Batch 0300/0500 | Cost: 0.5196
# Epoch: 036/050 | Batch 0400/0500 | Cost: 0.2559
# Epoch: 036/050 | Batch 0500/0500 | Cost: 0.3776
# epoch 36, skip_num 2324, loss 0.4354, train acc 87.118%, top_1 test acc 72.370%, top_5 test acc 92.730%
# EPOCH:  37 learning rate:  0.001
# Epoch: 037/050 | Batch 0100/0500 | Cost: 1.4155
# Epoch: 037/050 | Batch 0200/0500 | Cost: 0.4288
# Epoch: 037/050 | Batch 0300/0500 | Cost: 0.2793
# Epoch: 037/050 | Batch 0400/0500 | Cost: 0.4003
# Epoch: 037/050 | Batch 0500/0500 | Cost: 0.0885
# epoch 37, skip_num 2273, loss 0.4334, train acc 87.146%, top_1 test acc 72.220%, top_5 test acc 92.620%
# EPOCH:  38 learning rate:  0.001
# Epoch: 038/050 | Batch 0100/0500 | Cost: 0.6678
# Epoch: 038/050 | Batch 0200/0500 | Cost: 0.3793
# Epoch: 038/050 | Batch 0300/0500 | Cost: 0.3088
# Epoch: 038/050 | Batch 0400/0500 | Cost: 0.2027
# Epoch: 038/050 | Batch 0500/0500 | Cost: 0.9022
# epoch 38, skip_num 2317, loss 0.4155, train acc 87.874%, top_1 test acc 72.550%, top_5 test acc 92.870%
# EPOCH:  39 learning rate:  0.001
# Epoch: 039/050 | Batch 0100/0500 | Cost: 0.1880
# Epoch: 039/050 | Batch 0200/0500 | Cost: 0.3106
# Epoch: 039/050 | Batch 0300/0500 | Cost: 0.2029
# Epoch: 039/050 | Batch 0400/0500 | Cost: 0.2534
# Epoch: 039/050 | Batch 0500/0500 | Cost: 0.6526
# epoch 39, skip_num 2258, loss 0.4084, train acc 87.790%, top_1 test acc 72.400%, top_5 test acc 92.820%
# EPOCH:  40 learning rate:  0.001
# Epoch: 040/050 | Batch 0100/0500 | Cost: 0.1208
# Epoch: 040/050 | Batch 0200/0500 | Cost: 0.7184
# Epoch: 040/050 | Batch 0300/0500 | Cost: 0.2248
# Epoch: 040/050 | Batch 0400/0500 | Cost: 0.3393
# Epoch: 040/050 | Batch 0500/0500 | Cost: 0.4407
# epoch 40, skip_num 2300, loss 0.3979, train acc 88.394%, top_1 test acc 72.250%, top_5 test acc 92.690%
# EPOCH:  41 learning rate:  0.001
# Epoch: 041/050 | Batch 0100/0500 | Cost: 0.1922
# Epoch: 041/050 | Batch 0200/0500 | Cost: 0.2594
# Epoch: 041/050 | Batch 0300/0500 | Cost: 0.2714
# Epoch: 041/050 | Batch 0400/0500 | Cost: 0.1500
# Epoch: 041/050 | Batch 0500/0500 | Cost: 0.3608
# epoch 41, skip_num 2271, loss 0.3910, train acc 88.410%, top_1 test acc 72.370%, top_5 test acc 92.820%
# EPOCH:  42 learning rate:  0.001
# Epoch: 042/050 | Batch 0100/0500 | Cost: 0.5027
# Epoch: 042/050 | Batch 0200/0500 | Cost: 0.6753
# Epoch: 042/050 | Batch 0300/0500 | Cost: 0.4833
# Epoch: 042/050 | Batch 0400/0500 | Cost: 0.3207
# Epoch: 042/050 | Batch 0500/0500 | Cost: 0.4191
# epoch 42, skip_num 2281, loss 0.3822, train acc 88.810%, top_1 test acc 72.370%, top_5 test acc 92.790%
# EPOCH:  43 learning rate:  0.001
# Epoch: 043/050 | Batch 0100/0500 | Cost: 0.5555
# Epoch: 043/050 | Batch 0200/0500 | Cost: 0.4900
# Epoch: 043/050 | Batch 0300/0500 | Cost: 0.6769
# Epoch: 043/050 | Batch 0400/0500 | Cost: 0.6540
# Epoch: 043/050 | Batch 0500/0500 | Cost: 0.3328
# epoch 43, skip_num 2307, loss 0.3730, train acc 88.986%, top_1 test acc 72.320%, top_5 test acc 92.680%
# EPOCH:  44 learning rate:  0.001
# Epoch: 044/050 | Batch 0100/0500 | Cost: 0.6676
# Epoch: 044/050 | Batch 0200/0500 | Cost: 0.4106
# Epoch: 044/050 | Batch 0300/0500 | Cost: 0.2268
# Epoch: 044/050 | Batch 0400/0500 | Cost: 0.3079
# Epoch: 044/050 | Batch 0500/0500 | Cost: 0.6399
# epoch 44, skip_num 2274, loss 0.3661, train acc 89.158%, top_1 test acc 72.410%, top_5 test acc 92.500%
# EPOCH:  45 learning rate:  0.001
# Epoch: 045/050 | Batch 0100/0500 | Cost: 0.1021
# Epoch: 045/050 | Batch 0200/0500 | Cost: 0.3907
# Epoch: 045/050 | Batch 0300/0500 | Cost: 0.1031
# Epoch: 045/050 | Batch 0400/0500 | Cost: 0.1969
# Epoch: 045/050 | Batch 0500/0500 | Cost: 0.3810
# epoch 45, skip_num 2214, loss 0.3653, train acc 89.122%, top_1 test acc 72.200%, top_5 test acc 92.720%
# EPOCH:  46 learning rate:  0.001
# Epoch: 046/050 | Batch 0100/0500 | Cost: 0.1978
# Epoch: 046/050 | Batch 0200/0500 | Cost: 0.5846
# Epoch: 046/050 | Batch 0300/0500 | Cost: 0.7213
# Epoch: 046/050 | Batch 0400/0500 | Cost: 0.3048
# Epoch: 046/050 | Batch 0500/0500 | Cost: 0.0839
# epoch 46, skip_num 2263, loss 0.3548, train acc 89.536%, top_1 test acc 72.660%, top_5 test acc 92.650%
# EPOCH:  47 learning rate:  0.001
# Epoch: 047/050 | Batch 0100/0500 | Cost: 0.3662
# Epoch: 047/050 | Batch 0200/0500 | Cost: 0.3135
# Epoch: 047/050 | Batch 0300/0500 | Cost: 0.1863
# Epoch: 047/050 | Batch 0400/0500 | Cost: 0.0444
# Epoch: 047/050 | Batch 0500/0500 | Cost: 0.4190
# epoch 47, skip_num 2200, loss 0.3507, train acc 89.740%, top_1 test acc 72.610%, top_5 test acc 92.770%
# EPOCH:  48 learning rate:  0.001
# Epoch: 048/050 | Batch 0100/0500 | Cost: 0.4052
# Epoch: 048/050 | Batch 0200/0500 | Cost: 0.2956
# Epoch: 048/050 | Batch 0300/0500 | Cost: 0.0970
# Epoch: 048/050 | Batch 0400/0500 | Cost: 0.1065
# Epoch: 048/050 | Batch 0500/0500 | Cost: 0.1249
# epoch 48, skip_num 2211, loss 0.3458, train acc 89.624%, top_1 test acc 72.410%, top_5 test acc 92.680%
# EPOCH:  49 learning rate:  0.001
# Epoch: 049/050 | Batch 0100/0500 | Cost: 0.3135
# Epoch: 049/050 | Batch 0200/0500 | Cost: 0.5937
# Epoch: 049/050 | Batch 0300/0500 | Cost: 0.1484
# Epoch: 049/050 | Batch 0400/0500 | Cost: 0.1238
# Epoch: 049/050 | Batch 0500/0500 | Cost: 0.3260
# epoch 49, skip_num 2243, loss 0.3368, train acc 90.078%, top_1 test acc 72.300%, top_5 test acc 92.480%
# EPOCH:  50 learning rate:  0.001
# Epoch: 050/050 | Batch 0100/0500 | Cost: 0.3039
# Epoch: 050/050 | Batch 0200/0500 | Cost: 0.1502
# Epoch: 050/050 | Batch 0300/0500 | Cost: 0.6144
# Epoch: 050/050 | Batch 0400/0500 | Cost: 0.7134
# Epoch: 050/050 | Batch 0500/0500 | Cost: 0.2699
# epoch 50, skip_num 2234, loss 0.3360, train acc 90.078%, top_1 test acc 72.280%, top_5 test acc 92.590%
# Finished.

# %% [markdown]
# # LASG

# %%
print("LASG  lr:"+str(lr)+"--epoch:"+str(NUM_EPOCHS)+"--worker:"+str(NUM_WORKERS))
seed_torch(RANDOM_SEED)
model = resnet18()
model.to(DEVICE)
model_copy = resnet18_copy()
model_copy.to(DEVICE)
loss = nn.CrossEntropyLoss()  # 损失函数

# prepare data
dataset_name = 'cifar100'
train_loader_workers, test_loader = create_loaders(dataset_name, NUM_WORKERS, BATCH_SIZE)

NUM_PARAS = sum([1 for param in model.parameters()])
print("Number_parameter:", NUM_PARAS)
total_params = sum(p.numel() for p in model.parameters() if p.requires_grad)
print("Element_parameter:", total_params)

state_dict = [0 for col in range(NUM_WORKERS)]
grad_worker = [[0 for col in range(NUM_PARAS)] for row in range(NUM_WORKERS)]
grad_old = [0 for col in range(NUM_PARAS)]
grad_new = [0 for col in range(NUM_PARAS)]
para_store = [0 for col in range(NUM_PARAS)]
tau = [0 for col in range(NUM_WORKERS)]
para_list = []
Skip_epoch = []
Loss_epoch = []
train_acc_epoch = []
test_acc_epoch = []

Skip_iter = []
Loss_iter = []
train_acc_iter = []
test_acc_iter = []

iter_num = 0
skip_iter = 0
flag_acc = False

for epoch in range(NUM_EPOCHS):
    train_l_sum, train_acc_sum, num = 0.0, 0.0, 0
    train_loader_iter = [iter(train_loader_workers[w]) for w in range(NUM_WORKERS)]
    iter_steps = len(train_loader_workers[0])
    skip_num = [[0 for col in range(iter_steps)] for row in range(NUM_EPOCHS)]

    # adjust learning_rate
    lr, lr_thead = adjust_lr(epoch)
    print("EPOCH: ", epoch + 1, "learning rate: ", lr)

    for batch_idx in range(iter_steps):
        model.train()
        model_copy.train()
        grad_agg = [0 for col in range(NUM_PARAS)]
        skip_idx = 0
        if (epoch * iter_steps + batch_idx) < D:
            for w_id in range(NUM_WORKERS):
                images, labels = next(train_loader_iter[w_id])
                images, labels = images.to(DEVICE), labels.to(DEVICE)
                y_hat = model(images)
                Loss = loss(y_hat, labels)
                Loss.backward()
                with torch.no_grad():
                    p_id = 0
                    for p in model.parameters():
                        g = lr * p.grad.data.clone().detach()
                        grad_agg[p_id] += g
                        grad_worker[w_id][p_id] = g
                        p_id += 1
                        p.grad.zero_()
                state_dict[w_id] = copy.deepcopy(model.state_dict())
                train_l_sum += Loss.item()
                train_acc_sum += (y_hat.argmax(dim=1) == labels).sum().item()
                num += labels.shape[0]
        else:
            thread = 0.0
            with torch.no_grad():
                for i in range(len(para_list) - 1):
                    thread += compt(para_list[i], para_list[i + 1])
            thread = thread / (lr_thead * (NUM_WORKERS ** 2))
            for w_id in range(NUM_WORKERS):
                images, labels = next(train_loader_iter[w_id])
                images, labels = images.to(DEVICE), labels.to(DEVICE)
                model_copy.load_state_dict(state_dict[w_id])
                y_copy = model_copy(images)
                Loss_copy = loss(y_copy, labels)
                Loss_copy.backward()
                y_hat = model(images)
                Loss = loss(y_hat, labels)
                Loss.backward()
                with torch.no_grad():
                    p_old_id = 0
                    for p_old in model_copy.parameters():
                        grad_old[p_old_id] = p_old.grad.data.clone().detach()
                        p_old_id += 1
                        p_old.grad.zero_()
                    p_id = 0
                    for p in model.parameters():
                        grad_new[p_id] = p.grad.data.clone().detach()
                        p_id += 1
                    if compt(grad_old, grad_new) > 5.0 * thread or tau[w_id] > D:
                        tau[w_id] = 1
                        p_id = 0
                        for p in model.parameters():
                            g = lr * p.grad.data.clone().detach()
                            grad_agg[p_id] += g
                            grad_worker[w_id][p_id] = g
                            p_id += 1
                            p.grad.zero_()
                        state_dict[w_id] = copy.deepcopy(model.state_dict())
                    else:
                        skip_idx += 1
                        tau[w_id] += 1
                        p_id = 0
                        for p in model.parameters():
                            grad_agg[p_id] += grad_worker[w_id][p_id]
                            p_id += 1
                            p.grad.zero_()
                train_l_sum += Loss.item()
                train_acc_sum += (y_hat.argmax(dim=1) == labels).sum().item()
                num += labels.shape[0]
        skip_num[epoch][batch_idx] = skip_idx
        with torch.no_grad():
            p_id = 0
            for p in model.parameters():
                p.data.add_(grad_agg[p_id], alpha=-1)
                para_store[p_id] = p.data.clone().detach()
                p_id += 1
                p.grad.zero_()

            para_list.insert(0, para_store.copy())
            if len(para_list) > D:
                para_list.pop()
        # LOGGING
        if not (batch_idx + 1) % 100:
            print('Epoch: %03d/%03d | Batch %04d/%04d | Cost: %.4f'
                % (epoch + 1, NUM_EPOCHS, batch_idx + 1, len(train_loader_workers[0]), Loss.item()))

        iter_num += 1
        skip_iter += skip_idx
        if not iter_num % 100:
            model.eval()
            with torch.no_grad():
                _, test_acc_it = evaluate_accuracy(model, test_loader, DEVICE)
                Skip_iter.append(skip_iter)
                Loss_iter.append(train_l_sum / (num / BATCH_SIZE))
                train_acc_iter.append(train_acc_sum / num * 100)
                test_acc_iter.append(test_acc_it)
            if test_acc_it > 92.0 and not flag_acc:
                flag_acc = True
                print("*" * 100)
                print("Iter_num:", iter_num, "Test_acc", test_acc_it, "Skip_round:", skip_iter, "Comm_round:",
                    iter_num * 10 - skip_iter)  # 10 workers
                print("*" * 100)
    model.eval()
    with torch.no_grad():
        test_acc_1, test_acc_5 = evaluate_accuracy(model, test_loader, DEVICE)
        Skip_epoch.append(sum(skip_num[epoch]))
        Loss_epoch.append(train_l_sum / (num / BATCH_SIZE))
        train_acc_epoch.append(train_acc_sum / num * 100)
        test_acc_epoch.append(test_acc_5)
    print('epoch %d, skip_num %d, loss %.4f, train acc %.3f%%, top_1 test acc %.3f%%, top_5 test acc %.3f%%'
        % (epoch + 1, Skip_epoch[epoch], train_l_sum / (num / BATCH_SIZE), train_acc_sum / num * 100, test_acc_1, test_acc_5))

print('Finished.')

list_write = []
list_write.append(Skip_epoch)
list_write.append(Loss_epoch)
list_write.append(train_acc_epoch)
list_write.append(test_acc_epoch)
name = ['Skip', 'Loss', 'train-acc', 'test-acc']
test = pd.DataFrame(index=name, data=list_write).T
test.to_csv("./result/"+"LASG-res-cifar100.csv", encoding='gbk')

list_write_iter = []
list_write_iter.append(Skip_iter)
list_write_iter.append(Loss_iter)
list_write_iter.append(train_acc_iter)
list_write_iter.append(test_acc_iter)
name_iter = ['Skip', 'Loss', 'train-acc', 'test-acc']
test = pd.DataFrame(index=name_iter, data=list_write_iter).T
test.to_csv("./result/"+"LASG-res-cifar100-iter.csv", encoding='gbk')
# Out:
# LASG  lr:0.001--epoch:50--worker:10
# Files already downloaded and verified
# Files already downloaded and verified
# C:\Users\DxiaoG\AppData\Local\Temp\Mxt230\tmp\ipykernel_18272\1940885620.py:9: DeprecationWarning: `np.int` is a deprecated alias for the builtin `int`. To silence this warning, use `int` by itself. Doing this will not modify any behavior and is safe. When replacing `np.int`, you may wish to use e.g. `np.int64` or `np.int32` to specify the precision. If you wish to review your current use, check the release note link for additional information.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   a = np.int(np.floor(n / n_workers))
# Number_parameter: 62
# Element_parameter: 11220132
# EPOCH:  1 learning rate:  0.01
# Epoch: 001/050 | Batch 0100/0500 | Cost: 4.1686
# Epoch: 001/050 | Batch 0200/0500 | Cost: 3.8967
# Epoch: 001/050 | Batch 0300/0500 | Cost: 3.6776
# Epoch: 001/050 | Batch 0400/0500 | Cost: 2.9377
# Epoch: 001/050 | Batch 0500/0500 | Cost: 2.9671
# epoch 1, skip_num 0, loss 3.8246, train acc 11.236%, top_1 test acc 20.700%, top_5 test acc 48.680%
# EPOCH:  2 learning rate:  0.01
# Epoch: 002/050 | Batch 0100/0500 | Cost: 2.7775
# Epoch: 002/050 | Batch 0200/0500 | Cost: 2.6964
# Epoch: 002/050 | Batch 0300/0500 | Cost: 2.5813
# Epoch: 002/050 | Batch 0400/0500 | Cost: 3.4543
# Epoch: 002/050 | Batch 0500/0500 | Cost: 3.2158
# epoch 2, skip_num 0, loss 3.1313, train acc 22.786%, top_1 test acc 31.670%, top_5 test acc 62.820%
# EPOCH:  3 learning rate:  0.01
# Epoch: 003/050 | Batch 0100/0500 | Cost: 2.4393
# Epoch: 003/050 | Batch 0200/0500 | Cost: 2.0763
# Epoch: 003/050 | Batch 0300/0500 | Cost: 2.5158
# Epoch: 003/050 | Batch 0400/0500 | Cost: 2.0482
# Epoch: 003/050 | Batch 0500/0500 | Cost: 3.0710
# epoch 3, skip_num 0, loss 2.6979, train acc 30.990%, top_1 test acc 38.490%, top_5 test acc 70.180%
# EPOCH:  4 learning rate:  0.01
# Epoch: 004/050 | Batch 0100/0500 | Cost: 2.4956
# Epoch: 004/050 | Batch 0200/0500 | Cost: 2.2039
# Epoch: 004/050 | Batch 0300/0500 | Cost: 2.1118
# Epoch: 004/050 | Batch 0400/0500 | Cost: 2.6160
# Epoch: 004/050 | Batch 0500/0500 | Cost: 2.5548
# epoch 4, skip_num 0, loss 2.3891, train acc 37.558%, top_1 test acc 42.430%, top_5 test acc 75.530%
# EPOCH:  5 learning rate:  0.01
# Epoch: 005/050 | Batch 0100/0500 | Cost: 1.2874
# Epoch: 005/050 | Batch 0200/0500 | Cost: 1.8899
# Epoch: 005/050 | Batch 0300/0500 | Cost: 2.6168
# Epoch: 005/050 | Batch 0400/0500 | Cost: 1.8218
# Epoch: 005/050 | Batch 0500/0500 | Cost: 2.3653
# epoch 5, skip_num 0, loss 2.1713, train acc 42.310%, top_1 test acc 45.930%, top_5 test acc 77.860%
# EPOCH:  6 learning rate:  0.01
# Epoch: 006/050 | Batch 0100/0500 | Cost: 2.2362
# Epoch: 006/050 | Batch 0200/0500 | Cost: 2.4398
# Epoch: 006/050 | Batch 0300/0500 | Cost: 1.2461
# Epoch: 006/050 | Batch 0400/0500 | Cost: 2.0100
# Epoch: 006/050 | Batch 0500/0500 | Cost: 3.0784
# epoch 6, skip_num 2, loss 1.9976, train acc 46.020%, top_1 test acc 51.340%, top_5 test acc 81.360%
# EPOCH:  7 learning rate:  0.01
# Epoch: 007/050 | Batch 0100/0500 | Cost: 1.8322
# Epoch: 007/050 | Batch 0200/0500 | Cost: 1.7751
# Epoch: 007/050 | Batch 0300/0500 | Cost: 1.9931
# Epoch: 007/050 | Batch 0400/0500 | Cost: 2.3436
# Epoch: 007/050 | Batch 0500/0500 | Cost: 2.4806
# epoch 7, skip_num 4, loss 1.8629, train acc 49.178%, top_1 test acc 52.900%, top_5 test acc 82.180%
# EPOCH:  8 learning rate:  0.01
# Epoch: 008/050 | Batch 0100/0500 | Cost: 3.2955
# Epoch: 008/050 | Batch 0200/0500 | Cost: 0.6652
# Epoch: 008/050 | Batch 0300/0500 | Cost: 1.9569
# Epoch: 008/050 | Batch 0400/0500 | Cost: 1.4804
# Epoch: 008/050 | Batch 0500/0500 | Cost: 1.8893
# epoch 8, skip_num 13, loss 1.7513, train acc 51.976%, top_1 test acc 56.450%, top_5 test acc 84.710%
# EPOCH:  9 learning rate:  0.01
# Epoch: 009/050 | Batch 0100/0500 | Cost: 2.0615
# Epoch: 009/050 | Batch 0200/0500 | Cost: 2.7154
# Epoch: 009/050 | Batch 0300/0500 | Cost: 1.0263
# Epoch: 009/050 | Batch 0400/0500 | Cost: 1.8865
# Epoch: 009/050 | Batch 0500/0500 | Cost: 1.9395
# epoch 9, skip_num 24, loss 1.6496, train acc 54.200%, top_1 test acc 58.420%, top_5 test acc 85.780%
# EPOCH:  10 learning rate:  0.01
# Epoch: 010/050 | Batch 0100/0500 | Cost: 0.9965
# Epoch: 010/050 | Batch 0200/0500 | Cost: 1.0535
# Epoch: 010/050 | Batch 0300/0500 | Cost: 1.7690
# Epoch: 010/050 | Batch 0400/0500 | Cost: 1.1517
# Epoch: 010/050 | Batch 0500/0500 | Cost: 1.4766
# epoch 10, skip_num 27, loss 1.5699, train acc 56.328%, top_1 test acc 58.090%, top_5 test acc 85.580%
# EPOCH:  11 learning rate:  0.01
# Epoch: 011/050 | Batch 0100/0500 | Cost: 1.0343
# Epoch: 011/050 | Batch 0200/0500 | Cost: 1.0499
# Epoch: 011/050 | Batch 0300/0500 | Cost: 1.4392
# Epoch: 011/050 | Batch 0400/0500 | Cost: 2.6534
# Epoch: 011/050 | Batch 0500/0500 | Cost: 0.8741
# epoch 11, skip_num 62, loss 1.4905, train acc 58.238%, top_1 test acc 59.190%, top_5 test acc 86.460%
# EPOCH:  12 learning rate:  0.01
# Epoch: 012/050 | Batch 0100/0500 | Cost: 2.0690
# Epoch: 012/050 | Batch 0200/0500 | Cost: 1.8057
# Epoch: 012/050 | Batch 0300/0500 | Cost: 2.2743
# Epoch: 012/050 | Batch 0400/0500 | Cost: 1.0757
# Epoch: 012/050 | Batch 0500/0500 | Cost: 0.3626
# epoch 12, skip_num 74, loss 1.4311, train acc 59.534%, top_1 test acc 59.710%, top_5 test acc 86.830%
# EPOCH:  13 learning rate:  0.01
# Epoch: 013/050 | Batch 0100/0500 | Cost: 1.4434
# Epoch: 013/050 | Batch 0200/0500 | Cost: 0.5408
# Epoch: 013/050 | Batch 0300/0500 | Cost: 1.5737
# Epoch: 013/050 | Batch 0400/0500 | Cost: 1.4711
# Epoch: 013/050 | Batch 0500/0500 | Cost: 1.9872
# epoch 13, skip_num 92, loss 1.3624, train acc 61.164%, top_1 test acc 59.510%, top_5 test acc 86.550%
# EPOCH:  14 learning rate:  0.01
# Epoch: 014/050 | Batch 0100/0500 | Cost: 1.8181
# Epoch: 014/050 | Batch 0200/0500 | Cost: 1.2096
# Epoch: 014/050 | Batch 0300/0500 | Cost: 1.5089
# Epoch: 014/050 | Batch 0400/0500 | Cost: 1.3233
# Epoch: 014/050 | Batch 0500/0500 | Cost: 1.2500
# epoch 14, skip_num 106, loss 1.3161, train acc 62.262%, top_1 test acc 60.720%, top_5 test acc 87.300%
# EPOCH:  15 learning rate:  0.01
# Epoch: 015/050 | Batch 0100/0500 | Cost: 1.2945
# Epoch: 015/050 | Batch 0200/0500 | Cost: 1.5905
# Epoch: 015/050 | Batch 0300/0500 | Cost: 2.0063
# Epoch: 015/050 | Batch 0400/0500 | Cost: 2.0482
# Epoch: 015/050 | Batch 0500/0500 | Cost: 0.6772
# epoch 15, skip_num 133, loss 1.2580, train acc 63.924%, top_1 test acc 63.420%, top_5 test acc 88.230%
# EPOCH:  16 learning rate:  0.01
# Epoch: 016/050 | Batch 0100/0500 | Cost: 1.3577
# Epoch: 016/050 | Batch 0200/0500 | Cost: 2.3240
# Epoch: 016/050 | Batch 0300/0500 | Cost: 1.0109
# Epoch: 016/050 | Batch 0400/0500 | Cost: 1.4557
# Epoch: 016/050 | Batch 0500/0500 | Cost: 2.2306
# epoch 16, skip_num 187, loss 1.2124, train acc 65.078%, top_1 test acc 64.440%, top_5 test acc 89.040%
# EPOCH:  17 learning rate:  0.01
# Epoch: 017/050 | Batch 0100/0500 | Cost: 0.8547
# Epoch: 017/050 | Batch 0200/0500 | Cost: 0.7671
# Epoch: 017/050 | Batch 0300/0500 | Cost: 1.0504
# Epoch: 017/050 | Batch 0400/0500 | Cost: 1.1486
# Epoch: 017/050 | Batch 0500/0500 | Cost: 1.2154
# epoch 17, skip_num 225, loss 1.1687, train acc 66.160%, top_1 test acc 63.540%, top_5 test acc 88.850%
# EPOCH:  18 learning rate:  0.01
# Epoch: 018/050 | Batch 0100/0500 | Cost: 1.3299
# Epoch: 018/050 | Batch 0200/0500 | Cost: 1.7320
# Epoch: 018/050 | Batch 0300/0500 | Cost: 0.7703
# Epoch: 018/050 | Batch 0400/0500 | Cost: 1.8709
# Epoch: 018/050 | Batch 0500/0500 | Cost: 1.0549
# epoch 18, skip_num 210, loss 1.1251, train acc 67.226%, top_1 test acc 63.850%, top_5 test acc 88.590%
# EPOCH:  19 learning rate:  0.01
# Epoch: 019/050 | Batch 0100/0500 | Cost: 0.8143
# Epoch: 019/050 | Batch 0200/0500 | Cost: 1.4119
# Epoch: 019/050 | Batch 0300/0500 | Cost: 0.6940
# Epoch: 019/050 | Batch 0400/0500 | Cost: 0.8327
# Epoch: 019/050 | Batch 0500/0500 | Cost: 1.0516
# epoch 19, skip_num 275, loss 1.0903, train acc 68.190%, top_1 test acc 65.270%, top_5 test acc 89.480%
# EPOCH:  20 learning rate:  0.01
# Epoch: 020/050 | Batch 0100/0500 | Cost: 0.8238
# Epoch: 020/050 | Batch 0200/0500 | Cost: 0.1796
# Epoch: 020/050 | Batch 0300/0500 | Cost: 1.5441
# Epoch: 020/050 | Batch 0400/0500 | Cost: 2.0063
# Epoch: 020/050 | Batch 0500/0500 | Cost: 0.8845
# epoch 20, skip_num 312, loss 1.0510, train acc 69.244%, top_1 test acc 66.340%, top_5 test acc 90.000%
# EPOCH:  21 learning rate:  0.01
# Epoch: 021/050 | Batch 0100/0500 | Cost: 0.5527
# Epoch: 021/050 | Batch 0200/0500 | Cost: 1.2635
# Epoch: 021/050 | Batch 0300/0500 | Cost: 0.8143
# Epoch: 021/050 | Batch 0400/0500 | Cost: 1.9419
# Epoch: 021/050 | Batch 0500/0500 | Cost: 0.8421
# epoch 21, skip_num 340, loss 1.0169, train acc 70.008%, top_1 test acc 66.420%, top_5 test acc 90.090%
# EPOCH:  22 learning rate:  0.01
# Epoch: 022/050 | Batch 0100/0500 | Cost: 0.8033
# Epoch: 022/050 | Batch 0200/0500 | Cost: 1.6619
# Epoch: 022/050 | Batch 0300/0500 | Cost: 1.1144
# Epoch: 022/050 | Batch 0400/0500 | Cost: 1.9795
# Epoch: 022/050 | Batch 0500/0500 | Cost: 0.7152
# epoch 22, skip_num 401, loss 0.9864, train acc 70.788%, top_1 test acc 66.560%, top_5 test acc 90.060%
# EPOCH:  23 learning rate:  0.01
# Epoch: 023/050 | Batch 0100/0500 | Cost: 0.9672
# Epoch: 023/050 | Batch 0200/0500 | Cost: 1.0753
# Epoch: 023/050 | Batch 0300/0500 | Cost: 0.7144
# Epoch: 023/050 | Batch 0400/0500 | Cost: 0.4460
# Epoch: 023/050 | Batch 0500/0500 | Cost: 1.3502
# epoch 23, skip_num 416, loss 0.9523, train acc 71.638%, top_1 test acc 66.060%, top_5 test acc 89.970%
# EPOCH:  24 learning rate:  0.01
# Epoch: 024/050 | Batch 0100/0500 | Cost: 0.7077
# Epoch: 024/050 | Batch 0200/0500 | Cost: 0.7711
# Epoch: 024/050 | Batch 0300/0500 | Cost: 0.5022
# Epoch: 024/050 | Batch 0400/0500 | Cost: 1.0378
# Epoch: 024/050 | Batch 0500/0500 | Cost: 0.8177
# epoch 24, skip_num 481, loss 0.9297, train acc 72.360%, top_1 test acc 66.500%, top_5 test acc 90.020%
# EPOCH:  25 learning rate:  0.01
# Epoch: 025/050 | Batch 0100/0500 | Cost: 1.5050
# Epoch: 025/050 | Batch 0200/0500 | Cost: 0.5048
# Epoch: 025/050 | Batch 0300/0500 | Cost: 1.4938
# Epoch: 025/050 | Batch 0400/0500 | Cost: 1.1123
# Epoch: 025/050 | Batch 0500/0500 | Cost: 0.2954
# epoch 25, skip_num 502, loss 0.9049, train acc 73.032%, top_1 test acc 66.750%, top_5 test acc 90.320%
# EPOCH:  26 learning rate:  0.01
# Epoch: 026/050 | Batch 0100/0500 | Cost: 1.2674
# Epoch: 026/050 | Batch 0200/0500 | Cost: 0.6293
# Epoch: 026/050 | Batch 0300/0500 | Cost: 0.2876
# Epoch: 026/050 | Batch 0400/0500 | Cost: 0.8836
# Epoch: 026/050 | Batch 0500/0500 | Cost: 1.8443
# epoch 26, skip_num 534, loss 0.8731, train acc 73.634%, top_1 test acc 67.290%, top_5 test acc 90.050%
# EPOCH:  27 learning rate:  0.01
# Epoch: 027/050 | Batch 0100/0500 | Cost: 0.4454
# Epoch: 027/050 | Batch 0200/0500 | Cost: 0.4999
# Epoch: 027/050 | Batch 0300/0500 | Cost: 1.1431
# Epoch: 027/050 | Batch 0400/0500 | Cost: 0.3553
# Epoch: 027/050 | Batch 0500/0500 | Cost: 0.2971
# epoch 27, skip_num 602, loss 0.8476, train acc 74.598%, top_1 test acc 66.160%, top_5 test acc 90.160%
# EPOCH:  28 learning rate:  0.01
# Epoch: 028/050 | Batch 0100/0500 | Cost: 0.4694
# Epoch: 028/050 | Batch 0200/0500 | Cost: 0.6923
# Epoch: 028/050 | Batch 0300/0500 | Cost: 1.0634
# Epoch: 028/050 | Batch 0400/0500 | Cost: 0.8191
# Epoch: 028/050 | Batch 0500/0500 | Cost: 1.2192
# epoch 28, skip_num 615, loss 0.8238, train acc 75.250%, top_1 test acc 67.190%, top_5 test acc 90.500%
# EPOCH:  29 learning rate:  0.01
# Epoch: 029/050 | Batch 0100/0500 | Cost: 0.6538
# Epoch: 029/050 | Batch 0200/0500 | Cost: 0.9882
# Epoch: 029/050 | Batch 0300/0500 | Cost: 0.9533
# Epoch: 029/050 | Batch 0400/0500 | Cost: 1.2833
# Epoch: 029/050 | Batch 0500/0500 | Cost: 1.2745
# epoch 29, skip_num 678, loss 0.8025, train acc 75.800%, top_1 test acc 67.980%, top_5 test acc 90.860%
# EPOCH:  30 learning rate:  0.01
# Epoch: 030/050 | Batch 0100/0500 | Cost: 0.5506
# Epoch: 030/050 | Batch 0200/0500 | Cost: 0.7691
# Epoch: 030/050 | Batch 0300/0500 | Cost: 0.7013
# Epoch: 030/050 | Batch 0400/0500 | Cost: 0.9808
# Epoch: 030/050 | Batch 0500/0500 | Cost: 0.5077
# epoch 30, skip_num 738, loss 0.7850, train acc 76.236%, top_1 test acc 67.550%, top_5 test acc 90.500%
# EPOCH:  31 learning rate:  0.001
# Epoch: 031/050 | Batch 0100/0500 | Cost: 0.3023
# Epoch: 031/050 | Batch 0200/0500 | Cost: 0.6311
# Epoch: 031/050 | Batch 0300/0500 | Cost: 0.2327
# ****************************************************************************************************
# Iter_num: 15300 Test_acc 92.21 Skip_round: 7157 Comm_round: 145843
# ****************************************************************************************************
# Epoch: 031/050 | Batch 0400/0500 | Cost: 0.7335
# Epoch: 031/050 | Batch 0500/0500 | Cost: 0.9839
# epoch 31, skip_num 137, loss 0.5874, train acc 82.362%, top_1 test acc 72.180%, top_5 test acc 92.370%
# EPOCH:  32 learning rate:  0.001
# Epoch: 032/050 | Batch 0100/0500 | Cost: 0.5991
# Epoch: 032/050 | Batch 0200/0500 | Cost: 1.1938
# Epoch: 032/050 | Batch 0300/0500 | Cost: 1.4896
# Epoch: 032/050 | Batch 0400/0500 | Cost: 0.5356
# Epoch: 032/050 | Batch 0500/0500 | Cost: 0.5118
# epoch 32, skip_num 2383, loss 0.5352, train acc 83.980%, top_1 test acc 72.260%, top_5 test acc 92.420%
# EPOCH:  33 learning rate:  0.001
# Epoch: 033/050 | Batch 0100/0500 | Cost: 0.9843
# Epoch: 033/050 | Batch 0200/0500 | Cost: 0.9546
# Epoch: 033/050 | Batch 0300/0500 | Cost: 0.6514
# Epoch: 033/050 | Batch 0400/0500 | Cost: 0.3528
# Epoch: 033/050 | Batch 0500/0500 | Cost: 0.5943
# epoch 33, skip_num 2370, loss 0.5138, train acc 84.638%, top_1 test acc 72.400%, top_5 test acc 92.280%
# EPOCH:  34 learning rate:  0.001
# Epoch: 034/050 | Batch 0100/0500 | Cost: 1.0392
# Epoch: 034/050 | Batch 0200/0500 | Cost: 0.2830
# Epoch: 034/050 | Batch 0300/0500 | Cost: 1.4166
# Epoch: 034/050 | Batch 0400/0500 | Cost: 0.4911
# Epoch: 034/050 | Batch 0500/0500 | Cost: 0.5353
# epoch 34, skip_num 2372, loss 0.5008, train acc 85.138%, top_1 test acc 72.620%, top_5 test acc 92.170%
# EPOCH:  35 learning rate:  0.001
# Epoch: 035/050 | Batch 0100/0500 | Cost: 0.1559
# Epoch: 035/050 | Batch 0200/0500 | Cost: 0.0669
# Epoch: 035/050 | Batch 0300/0500 | Cost: 0.4583
# Epoch: 035/050 | Batch 0400/0500 | Cost: 0.6384
# Epoch: 035/050 | Batch 0500/0500 | Cost: 0.5905
# epoch 35, skip_num 2374, loss 0.4786, train acc 85.954%, top_1 test acc 72.490%, top_5 test acc 92.300%
# EPOCH:  36 learning rate:  0.001
# Epoch: 036/050 | Batch 0100/0500 | Cost: 0.8258
# Epoch: 036/050 | Batch 0200/0500 | Cost: 0.3288
# Epoch: 036/050 | Batch 0300/0500 | Cost: 0.5573
# Epoch: 036/050 | Batch 0400/0500 | Cost: 0.3454
# Epoch: 036/050 | Batch 0500/0500 | Cost: 0.2215
# epoch 36, skip_num 2298, loss 0.4725, train acc 85.974%, top_1 test acc 72.860%, top_5 test acc 92.580%
# EPOCH:  37 learning rate:  0.001
# Epoch: 037/050 | Batch 0100/0500 | Cost: 0.8199
# Epoch: 037/050 | Batch 0200/0500 | Cost: 0.5584
# Epoch: 037/050 | Batch 0300/0500 | Cost: 0.3865
# Epoch: 037/050 | Batch 0400/0500 | Cost: 0.4257
# Epoch: 037/050 | Batch 0500/0500 | Cost: 0.1603
# epoch 37, skip_num 2284, loss 0.4669, train acc 86.156%, top_1 test acc 72.370%, top_5 test acc 92.500%
# EPOCH:  38 learning rate:  0.001
# Epoch: 038/050 | Batch 0100/0500 | Cost: 0.4676
# Epoch: 038/050 | Batch 0200/0500 | Cost: 0.3382
# Epoch: 038/050 | Batch 0300/0500 | Cost: 0.4041
# Epoch: 038/050 | Batch 0400/0500 | Cost: 0.1986
# Epoch: 038/050 | Batch 0500/0500 | Cost: 0.6265
# epoch 38, skip_num 2293, loss 0.4510, train acc 86.712%, top_1 test acc 72.590%, top_5 test acc 92.470%
# EPOCH:  39 learning rate:  0.001
# Epoch: 039/050 | Batch 0100/0500 | Cost: 0.3252
# Epoch: 039/050 | Batch 0200/0500 | Cost: 0.4934
# Epoch: 039/050 | Batch 0300/0500 | Cost: 0.3148
# Epoch: 039/050 | Batch 0400/0500 | Cost: 0.2699
# Epoch: 039/050 | Batch 0500/0500 | Cost: 0.5373
# epoch 39, skip_num 2273, loss 0.4395, train acc 86.998%, top_1 test acc 72.650%, top_5 test acc 92.540%
# EPOCH:  40 learning rate:  0.001
# Epoch: 040/050 | Batch 0100/0500 | Cost: 0.2187
# Epoch: 040/050 | Batch 0200/0500 | Cost: 0.7625
# Epoch: 040/050 | Batch 0300/0500 | Cost: 0.2766
# Epoch: 040/050 | Batch 0400/0500 | Cost: 0.2028
# Epoch: 040/050 | Batch 0500/0500 | Cost: 0.2050
# epoch 40, skip_num 2260, loss 0.4308, train acc 87.326%, top_1 test acc 72.900%, top_5 test acc 92.780%
# EPOCH:  41 learning rate:  0.001
# Epoch: 041/050 | Batch 0100/0500 | Cost: 0.2206
# Epoch: 041/050 | Batch 0200/0500 | Cost: 0.3781
# Epoch: 041/050 | Batch 0300/0500 | Cost: 0.4970
# Epoch: 041/050 | Batch 0400/0500 | Cost: 0.1822
# Epoch: 041/050 | Batch 0500/0500 | Cost: 0.5812
# epoch 41, skip_num 2204, loss 0.4244, train acc 87.540%, top_1 test acc 72.450%, top_5 test acc 92.640%
# EPOCH:  42 learning rate:  0.001
# Epoch: 042/050 | Batch 0100/0500 | Cost: 0.4733
# Epoch: 042/050 | Batch 0200/0500 | Cost: 0.6938
# Epoch: 042/050 | Batch 0300/0500 | Cost: 0.5005
# Epoch: 042/050 | Batch 0400/0500 | Cost: 0.0771
# Epoch: 042/050 | Batch 0500/0500 | Cost: 0.5672
# epoch 42, skip_num 2250, loss 0.4129, train acc 87.904%, top_1 test acc 72.110%, top_5 test acc 92.640%
# EPOCH:  43 learning rate:  0.001
# Epoch: 043/050 | Batch 0100/0500 | Cost: 0.5846
# Epoch: 043/050 | Batch 0200/0500 | Cost: 0.5858
# Epoch: 043/050 | Batch 0300/0500 | Cost: 0.4276
# Epoch: 043/050 | Batch 0400/0500 | Cost: 0.7453
# Epoch: 043/050 | Batch 0500/0500 | Cost: 0.6086
# epoch 43, skip_num 2199, loss 0.4083, train acc 87.948%, top_1 test acc 72.810%, top_5 test acc 92.390%
# EPOCH:  44 learning rate:  0.001
# Epoch: 044/050 | Batch 0100/0500 | Cost: 0.8296
# Epoch: 044/050 | Batch 0200/0500 | Cost: 0.6570
# Epoch: 044/050 | Batch 0300/0500 | Cost: 0.2636
# Epoch: 044/050 | Batch 0400/0500 | Cost: 0.4647
# Epoch: 044/050 | Batch 0500/0500 | Cost: 0.3566
# epoch 44, skip_num 2221, loss 0.4018, train acc 88.188%, top_1 test acc 72.660%, top_5 test acc 92.620%
# EPOCH:  45 learning rate:  0.001
# Epoch: 045/050 | Batch 0100/0500 | Cost: 0.1433
# Epoch: 045/050 | Batch 0200/0500 | Cost: 0.4824
# Epoch: 045/050 | Batch 0300/0500 | Cost: 0.2363
# Epoch: 045/050 | Batch 0400/0500 | Cost: 0.6233
# Epoch: 045/050 | Batch 0500/0500 | Cost: 0.4001
# epoch 45, skip_num 2172, loss 0.3971, train acc 88.388%, top_1 test acc 72.440%, top_5 test acc 92.620%
# EPOCH:  46 learning rate:  0.001
# Epoch: 046/050 | Batch 0100/0500 | Cost: 0.2282
# Epoch: 046/050 | Batch 0200/0500 | Cost: 0.7641
# Epoch: 046/050 | Batch 0300/0500 | Cost: 0.6935
# Epoch: 046/050 | Batch 0400/0500 | Cost: 0.2976
# Epoch: 046/050 | Batch 0500/0500 | Cost: 0.1485
# epoch 46, skip_num 2151, loss 0.3884, train acc 88.466%, top_1 test acc 72.470%, top_5 test acc 92.670%
# EPOCH:  47 learning rate:  0.001
# Epoch: 047/050 | Batch 0100/0500 | Cost: 0.3980
# Epoch: 047/050 | Batch 0200/0500 | Cost: 0.3951
# Epoch: 047/050 | Batch 0300/0500 | Cost: 0.0887
# Epoch: 047/050 | Batch 0400/0500 | Cost: 0.1257
# Epoch: 047/050 | Batch 0500/0500 | Cost: 0.7620
# epoch 47, skip_num 2121, loss 0.3875, train acc 88.596%, top_1 test acc 72.640%, top_5 test acc 92.860%
# EPOCH:  48 learning rate:  0.001
# Epoch: 048/050 | Batch 0100/0500 | Cost: 0.6313
# Epoch: 048/050 | Batch 0200/0500 | Cost: 0.3259
# Epoch: 048/050 | Batch 0300/0500 | Cost: 0.2567
# Epoch: 048/050 | Batch 0400/0500 | Cost: 0.0841
# Epoch: 048/050 | Batch 0500/0500 | Cost: 0.3625
# epoch 48, skip_num 2159, loss 0.3784, train acc 88.846%, top_1 test acc 72.380%, top_5 test acc 92.740%
# EPOCH:  49 learning rate:  0.001
# Epoch: 049/050 | Batch 0100/0500 | Cost: 0.2212
# Epoch: 049/050 | Batch 0200/0500 | Cost: 0.5359
# Epoch: 049/050 | Batch 0300/0500 | Cost: 0.5055
# Epoch: 049/050 | Batch 0400/0500 | Cost: 0.1324
# Epoch: 049/050 | Batch 0500/0500 | Cost: 0.2142
# epoch 49, skip_num 2166, loss 0.3683, train acc 89.176%, top_1 test acc 72.150%, top_5 test acc 92.690%
# EPOCH:  50 learning rate:  0.001
# Epoch: 050/050 | Batch 0100/0500 | Cost: 0.3165
# Epoch: 050/050 | Batch 0200/0500 | Cost: 0.1867
# Epoch: 050/050 | Batch 0300/0500 | Cost: 0.2421
# Epoch: 050/050 | Batch 0400/0500 | Cost: 0.8995
# Epoch: 050/050 | Batch 0500/0500 | Cost: 0.2253
# epoch 50, skip_num 2136, loss 0.3687, train acc 88.998%, top_1 test acc 72.220%, top_5 test acc 92.450%
# Finished.

# %% [markdown]
# # Sparse

# %%
print("Sparse  lr:"+str(lr)+"--h:"+str(h)+"--epoch:"+str(NUM_EPOCHS)+"--worker:"+str(NUM_WORKERS))
seed_torch(RANDOM_SEED)
model = resnet18()
model.to(DEVICE)
loss = nn.CrossEntropyLoss()  # 损失函数

# prepare data
dataset_name = 'cifar100'
train_loader_workers, test_loader = create_loaders(dataset_name, NUM_WORKERS, BATCH_SIZE)

NUM_PARAS = sum([1 for param in model.parameters()])
print("Number_parameter:", NUM_PARAS)
total_params = sum(p.numel() for p in model.parameters() if p.requires_grad)
print("Element_parameter:", total_params)

error_worker = [[0 for col in range(NUM_PARAS)] for row in range(NUM_WORKERS)]
Loss_epoch = []
train_acc_epoch = []
test_acc_epoch = []
Loss_iter = []
train_acc_iter = []
test_acc_iter = []
iter_num = 0
flag_acc = False

for epoch in range(NUM_EPOCHS):
    train_l_sum, train_acc_sum, num = 0.0, 0.0, 0
    train_loader_iter = [iter(train_loader_workers[w]) for w in range(NUM_WORKERS)]
    iter_steps = len(train_loader_workers[0])

    # adjust learning_rate
    lr, _ = adjust_lr(epoch)
    print("EPOCH: ", epoch + 1, "learning rate: ", lr)

    for batch_idx in range(iter_steps):
        model.train()
        grad_agg = [0 for col in range(NUM_PARAS)]
        for w_id in range(NUM_WORKERS):
            images, labels = next(train_loader_iter[w_id])
            images, labels = images.to(DEVICE), labels.to(DEVICE)
            y_hat = model(images)
            Loss = loss(y_hat, labels)
            Loss.backward()
            with torch.no_grad():
                p_id = 0
                for p in model.parameters():
                    g = lr * p.grad.data.clone().detach() + error_worker[w_id][p_id]
                    Tk_sparse = top_k_opt(g, h)
                    grad_agg[p_id] += Tk_sparse
                    error_worker[w_id][p_id] = g - Tk_sparse
                    p_id += 1
                    p.grad.zero_()
            train_l_sum += Loss.item()
            train_acc_sum += (y_hat.argmax(dim=1) == labels).sum().item()
            num += labels.shape[0]
        with torch.no_grad():
            p_id = 0
            for p in model.parameters():
                p.data.add_(grad_agg[p_id], alpha=-1)
                p_id += 1
                p.grad.zero_()
        # LOGGING
        if not (batch_idx + 1) % 100:
            print('Epoch: %03d/%03d | Batch %04d/%04d | Cost: %.4f'
                % (epoch + 1, NUM_EPOCHS, batch_idx + 1, len(train_loader_workers[0]), Loss.item()))
        iter_num += 1
        if not iter_num % 100:
            model.eval()
            with torch.no_grad():
                _, test_acc_it = evaluate_accuracy(model, test_loader, DEVICE)
                Loss_iter.append(train_l_sum / (num / BATCH_SIZE))
                train_acc_iter.append(train_acc_sum / num * 100)
                test_acc_iter.append(test_acc_it)
            if test_acc_it > 92.0 and not flag_acc:
                flag_acc = True
                print("*" * 100)
                print("Iter_num:", iter_num, "Test_acc", test_acc_it, "Comm_round:", iter_num * 10)  # 10 workers
                print("*" * 100)
    model.eval()
    with torch.no_grad():
        test_acc_1, test_acc_5 = evaluate_accuracy(model, test_loader, DEVICE)
        Loss_epoch.append(train_l_sum / (num / BATCH_SIZE))
        train_acc_epoch.append(train_acc_sum / num * 100)
        test_acc_epoch.append(test_acc_5)
    print('epoch %d, loss %.4f, train acc %.3f%%, top_1 test acc %.3f%%, top_5 test acc %.3f%%'
        % (epoch + 1, train_l_sum / (num / BATCH_SIZE), train_acc_sum / num * 100, test_acc_1, test_acc_5))

print('Finished.')

list_write = []
list_write.append(Loss_epoch)
list_write.append(train_acc_epoch)
list_write.append(test_acc_epoch)
name = ['Loss', 'train-acc', 'test-acc']
test = pd.DataFrame(index=name, data=list_write).T
test.to_csv("./result/"+"Sparse-res-cifar100.csv", encoding='gbk')


list_write_iter = []
list_write_iter.append(Loss_iter)
list_write_iter.append(train_acc_iter)
list_write_iter.append(test_acc_iter)
name_iter = ['Loss', 'train-acc', 'test-acc']
test = pd.DataFrame(index=name_iter, data=list_write_iter).T
test.to_csv("./result/"+"Sparse-res-cifar100-iter.csv", encoding='gbk')
# Out:
# Sparse  lr:0.001--h:0.01--epoch:50--worker:10
# Files already downloaded and verified
# Files already downloaded and verified
# C:\Users\DxiaoG\AppData\Local\Temp\Mxt230\tmp\ipykernel_18272\1940885620.py:9: DeprecationWarning: `np.int` is a deprecated alias for the builtin `int`. To silence this warning, use `int` by itself. Doing this will not modify any behavior and is safe. When replacing `np.int`, you may wish to use e.g. `np.int64` or `np.int32` to specify the precision. If you wish to review your current use, check the release note link for additional information.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   a = np.int(np.floor(n / n_workers))
# Number_parameter: 62
# Element_parameter: 11220132
# EPOCH:  1 learning rate:  0.01
# Epoch: 001/050 | Batch 0100/0500 | Cost: 3.5926
# Epoch: 001/050 | Batch 0200/0500 | Cost: 3.2911
# Epoch: 001/050 | Batch 0300/0500 | Cost: 3.0928
# Epoch: 001/050 | Batch 0400/0500 | Cost: 3.4034
# Epoch: 001/050 | Batch 0500/0500 | Cost: 3.0293
# epoch 1, loss 3.7387, train acc 12.990%, top_1 test acc 22.850%, top_5 test acc 52.300%
# EPOCH:  2 learning rate:  0.01
# Epoch: 002/050 | Batch 0100/0500 | Cost: 3.5586
# Epoch: 002/050 | Batch 0200/0500 | Cost: 3.4914
# Epoch: 002/050 | Batch 0300/0500 | Cost: 3.0785
# Epoch: 002/050 | Batch 0400/0500 | Cost: 2.5742
# Epoch: 002/050 | Batch 0500/0500 | Cost: 3.7292
# epoch 2, loss 2.9938, train acc 25.384%, top_1 test acc 34.620%, top_5 test acc 66.900%
# EPOCH:  3 learning rate:  0.01
# Epoch: 003/050 | Batch 0100/0500 | Cost: 2.5078
# Epoch: 003/050 | Batch 0200/0500 | Cost: 3.8418
# Epoch: 003/050 | Batch 0300/0500 | Cost: 3.0075
# Epoch: 003/050 | Batch 0400/0500 | Cost: 1.8790
# Epoch: 003/050 | Batch 0500/0500 | Cost: 2.6622
# epoch 3, loss 2.5691, train acc 34.044%, top_1 test acc 43.030%, top_5 test acc 75.290%
# EPOCH:  4 learning rate:  0.01
# Epoch: 004/050 | Batch 0100/0500 | Cost: 1.5593
# Epoch: 004/050 | Batch 0200/0500 | Cost: 2.2344
# Epoch: 004/050 | Batch 0300/0500 | Cost: 1.8416
# Epoch: 004/050 | Batch 0400/0500 | Cost: 2.3294
# Epoch: 004/050 | Batch 0500/0500 | Cost: 2.5881
# epoch 4, loss 2.2666, train acc 40.418%, top_1 test acc 47.110%, top_5 test acc 78.240%
# EPOCH:  5 learning rate:  0.01
# Epoch: 005/050 | Batch 0100/0500 | Cost: 2.3902
# Epoch: 005/050 | Batch 0200/0500 | Cost: 2.4679
# Epoch: 005/050 | Batch 0300/0500 | Cost: 1.3787
# Epoch: 005/050 | Batch 0400/0500 | Cost: 1.9615
# Epoch: 005/050 | Batch 0500/0500 | Cost: 3.0361
# epoch 5, loss 2.0660, train acc 44.878%, top_1 test acc 51.430%, top_5 test acc 80.880%
# EPOCH:  6 learning rate:  0.01
# Epoch: 006/050 | Batch 0100/0500 | Cost: 2.0290
# Epoch: 006/050 | Batch 0200/0500 | Cost: 1.9851
# Epoch: 006/050 | Batch 0300/0500 | Cost: 1.7652
# Epoch: 006/050 | Batch 0400/0500 | Cost: 1.2683
# Epoch: 006/050 | Batch 0500/0500 | Cost: 3.3592
# epoch 6, loss 1.9052, train acc 48.540%, top_1 test acc 53.330%, top_5 test acc 82.250%
# EPOCH:  7 learning rate:  0.01
# Epoch: 007/050 | Batch 0100/0500 | Cost: 1.4736
# Epoch: 007/050 | Batch 0200/0500 | Cost: 2.0463
# Epoch: 007/050 | Batch 0300/0500 | Cost: 1.5387
# Epoch: 007/050 | Batch 0400/0500 | Cost: 1.3471
# Epoch: 007/050 | Batch 0500/0500 | Cost: 2.5427
# epoch 7, loss 1.7757, train acc 51.496%, top_1 test acc 56.390%, top_5 test acc 84.160%
# EPOCH:  8 learning rate:  0.01
# Epoch: 008/050 | Batch 0100/0500 | Cost: 1.2310
# Epoch: 008/050 | Batch 0200/0500 | Cost: 0.9221
# Epoch: 008/050 | Batch 0300/0500 | Cost: 0.8649
# Epoch: 008/050 | Batch 0400/0500 | Cost: 2.2167
# Epoch: 008/050 | Batch 0500/0500 | Cost: 1.6804
# epoch 8, loss 1.6533, train acc 54.482%, top_1 test acc 57.530%, top_5 test acc 85.350%
# EPOCH:  9 learning rate:  0.01
# Epoch: 009/050 | Batch 0100/0500 | Cost: 2.5463
# Epoch: 009/050 | Batch 0200/0500 | Cost: 1.2261
# Epoch: 009/050 | Batch 0300/0500 | Cost: 1.2777
# Epoch: 009/050 | Batch 0400/0500 | Cost: 2.0375
# Epoch: 009/050 | Batch 0500/0500 | Cost: 1.4096
# epoch 9, loss 1.5750, train acc 56.162%, top_1 test acc 58.580%, top_5 test acc 85.650%
# EPOCH:  10 learning rate:  0.01
# Epoch: 010/050 | Batch 0100/0500 | Cost: 1.3082
# Epoch: 010/050 | Batch 0200/0500 | Cost: 1.9645
# Epoch: 010/050 | Batch 0300/0500 | Cost: 1.5519
# Epoch: 010/050 | Batch 0400/0500 | Cost: 1.0388
# Epoch: 010/050 | Batch 0500/0500 | Cost: 2.3772
# epoch 10, loss 1.4808, train acc 58.514%, top_1 test acc 60.730%, top_5 test acc 87.040%
# EPOCH:  11 learning rate:  0.01
# Epoch: 011/050 | Batch 0100/0500 | Cost: 1.0610
# Epoch: 011/050 | Batch 0200/0500 | Cost: 1.1503
# Epoch: 011/050 | Batch 0300/0500 | Cost: 1.0891
# Epoch: 011/050 | Batch 0400/0500 | Cost: 1.2134
# Epoch: 011/050 | Batch 0500/0500 | Cost: 2.2696
# epoch 11, loss 1.4076, train acc 60.358%, top_1 test acc 61.800%, top_5 test acc 87.520%
# EPOCH:  12 learning rate:  0.01
# Epoch: 012/050 | Batch 0100/0500 | Cost: 1.6213
# Epoch: 012/050 | Batch 0200/0500 | Cost: 1.0275
# Epoch: 012/050 | Batch 0300/0500 | Cost: 0.9023
# Epoch: 012/050 | Batch 0400/0500 | Cost: 0.9569
# Epoch: 012/050 | Batch 0500/0500 | Cost: 0.8759
# epoch 12, loss 1.3389, train acc 62.276%, top_1 test acc 62.280%, top_5 test acc 87.820%
# EPOCH:  13 learning rate:  0.01
# Epoch: 013/050 | Batch 0100/0500 | Cost: 1.5269
# Epoch: 013/050 | Batch 0200/0500 | Cost: 1.5790
# Epoch: 013/050 | Batch 0300/0500 | Cost: 1.2970
# Epoch: 013/050 | Batch 0400/0500 | Cost: 1.6536
# Epoch: 013/050 | Batch 0500/0500 | Cost: 1.2160
# epoch 13, loss 1.2813, train acc 63.660%, top_1 test acc 63.290%, top_5 test acc 88.250%
# EPOCH:  14 learning rate:  0.01
# Epoch: 014/050 | Batch 0100/0500 | Cost: 1.0865
# Epoch: 014/050 | Batch 0200/0500 | Cost: 1.1172
# Epoch: 014/050 | Batch 0300/0500 | Cost: 0.8773
# Epoch: 014/050 | Batch 0400/0500 | Cost: 1.3743
# Epoch: 014/050 | Batch 0500/0500 | Cost: 1.7778
# epoch 14, loss 1.2184, train acc 65.164%, top_1 test acc 65.020%, top_5 test acc 89.230%
# EPOCH:  15 learning rate:  0.01
# Epoch: 015/050 | Batch 0100/0500 | Cost: 0.6661
# Epoch: 015/050 | Batch 0200/0500 | Cost: 0.8288
# Epoch: 015/050 | Batch 0300/0500 | Cost: 1.4431
# Epoch: 015/050 | Batch 0400/0500 | Cost: 1.0430
# Epoch: 015/050 | Batch 0500/0500 | Cost: 1.3501
# epoch 15, loss 1.1778, train acc 66.008%, top_1 test acc 64.980%, top_5 test acc 89.330%
# EPOCH:  16 learning rate:  0.01
# Epoch: 016/050 | Batch 0100/0500 | Cost: 0.6930
# Epoch: 016/050 | Batch 0200/0500 | Cost: 1.4607
# Epoch: 016/050 | Batch 0300/0500 | Cost: 0.6514
# Epoch: 016/050 | Batch 0400/0500 | Cost: 0.6551
# Epoch: 016/050 | Batch 0500/0500 | Cost: 1.4402
# epoch 16, loss 1.1262, train acc 67.298%, top_1 test acc 65.430%, top_5 test acc 89.180%
# EPOCH:  17 learning rate:  0.01
# Epoch: 017/050 | Batch 0100/0500 | Cost: 1.6004
# Epoch: 017/050 | Batch 0200/0500 | Cost: 1.3228
# Epoch: 017/050 | Batch 0300/0500 | Cost: 1.4776
# Epoch: 017/050 | Batch 0400/0500 | Cost: 1.4057
# Epoch: 017/050 | Batch 0500/0500 | Cost: 1.2657
# epoch 17, loss 1.0793, train acc 68.514%, top_1 test acc 65.760%, top_5 test acc 89.940%
# EPOCH:  18 learning rate:  0.01
# Epoch: 018/050 | Batch 0100/0500 | Cost: 0.2649
# Epoch: 018/050 | Batch 0200/0500 | Cost: 0.9132
# Epoch: 018/050 | Batch 0300/0500 | Cost: 0.6017
# Epoch: 018/050 | Batch 0400/0500 | Cost: 0.9450
# Epoch: 018/050 | Batch 0500/0500 | Cost: 0.7517
# epoch 18, loss 1.0348, train acc 69.656%, top_1 test acc 66.770%, top_5 test acc 90.160%
# EPOCH:  19 learning rate:  0.01
# Epoch: 019/050 | Batch 0100/0500 | Cost: 0.6519
# Epoch: 019/050 | Batch 0200/0500 | Cost: 1.0179
# Epoch: 019/050 | Batch 0300/0500 | Cost: 1.3586
# Epoch: 019/050 | Batch 0400/0500 | Cost: 0.9662
# Epoch: 019/050 | Batch 0500/0500 | Cost: 0.8971
# epoch 19, loss 0.9974, train acc 70.664%, top_1 test acc 66.870%, top_5 test acc 90.020%
# EPOCH:  20 learning rate:  0.01
# Epoch: 020/050 | Batch 0100/0500 | Cost: 1.2505
# Epoch: 020/050 | Batch 0200/0500 | Cost: 0.4818
# Epoch: 020/050 | Batch 0300/0500 | Cost: 1.2973
# Epoch: 020/050 | Batch 0400/0500 | Cost: 0.6872
# Epoch: 020/050 | Batch 0500/0500 | Cost: 0.7892
# epoch 20, loss 0.9547, train acc 71.782%, top_1 test acc 66.840%, top_5 test acc 90.320%
# EPOCH:  21 learning rate:  0.01
# Epoch: 021/050 | Batch 0100/0500 | Cost: 1.0270
# Epoch: 021/050 | Batch 0200/0500 | Cost: 0.2930
# Epoch: 021/050 | Batch 0300/0500 | Cost: 1.5323
# Epoch: 021/050 | Batch 0400/0500 | Cost: 0.4892
# Epoch: 021/050 | Batch 0500/0500 | Cost: 1.4194
# epoch 21, loss 0.9236, train acc 72.554%, top_1 test acc 67.010%, top_5 test acc 90.210%
# EPOCH:  22 learning rate:  0.01
# Epoch: 022/050 | Batch 0100/0500 | Cost: 0.7574
# Epoch: 022/050 | Batch 0200/0500 | Cost: 0.3269
# Epoch: 022/050 | Batch 0300/0500 | Cost: 0.5351
# Epoch: 022/050 | Batch 0400/0500 | Cost: 1.4486
# Epoch: 022/050 | Batch 0500/0500 | Cost: 1.7309
# epoch 22, loss 0.8849, train acc 73.668%, top_1 test acc 68.290%, top_5 test acc 90.870%
# EPOCH:  23 learning rate:  0.01
# Epoch: 023/050 | Batch 0100/0500 | Cost: 0.9290
# Epoch: 023/050 | Batch 0200/0500 | Cost: 0.2568
# Epoch: 023/050 | Batch 0300/0500 | Cost: 1.0786
# Epoch: 023/050 | Batch 0400/0500 | Cost: 0.9822
# Epoch: 023/050 | Batch 0500/0500 | Cost: 0.8423
# epoch 23, loss 0.8470, train acc 74.530%, top_1 test acc 67.790%, top_5 test acc 90.990%
# EPOCH:  24 learning rate:  0.01
# Epoch: 024/050 | Batch 0100/0500 | Cost: 1.1753
# Epoch: 024/050 | Batch 0200/0500 | Cost: 0.8370
# Epoch: 024/050 | Batch 0300/0500 | Cost: 0.6308
# Epoch: 024/050 | Batch 0400/0500 | Cost: 0.9491
# Epoch: 024/050 | Batch 0500/0500 | Cost: 0.6851
# epoch 24, loss 0.8144, train acc 75.296%, top_1 test acc 67.970%, top_5 test acc 90.610%
# EPOCH:  25 learning rate:  0.01
# Epoch: 025/050 | Batch 0100/0500 | Cost: 0.9615
# Epoch: 025/050 | Batch 0200/0500 | Cost: 1.1433
# Epoch: 025/050 | Batch 0300/0500 | Cost: 1.1450
# Epoch: 025/050 | Batch 0400/0500 | Cost: 0.8050
# Epoch: 025/050 | Batch 0500/0500 | Cost: 0.6638
# epoch 25, loss 0.7913, train acc 75.976%, top_1 test acc 69.040%, top_5 test acc 90.740%
# EPOCH:  26 learning rate:  0.01
# Epoch: 026/050 | Batch 0100/0500 | Cost: 1.4109
# Epoch: 026/050 | Batch 0200/0500 | Cost: 0.8194
# Epoch: 026/050 | Batch 0300/0500 | Cost: 0.5040
# Epoch: 026/050 | Batch 0400/0500 | Cost: 1.0820
# Epoch: 026/050 | Batch 0500/0500 | Cost: 0.4774
# epoch 26, loss 0.7598, train acc 76.766%, top_1 test acc 69.500%, top_5 test acc 91.260%
# EPOCH:  27 learning rate:  0.01
# Epoch: 027/050 | Batch 0100/0500 | Cost: 1.7417
# Epoch: 027/050 | Batch 0200/0500 | Cost: 0.4486
# Epoch: 027/050 | Batch 0300/0500 | Cost: 1.3902
# Epoch: 027/050 | Batch 0400/0500 | Cost: 0.5215
# Epoch: 027/050 | Batch 0500/0500 | Cost: 1.4921
# epoch 27, loss 0.7279, train acc 77.922%, top_1 test acc 68.460%, top_5 test acc 90.990%
# EPOCH:  28 learning rate:  0.01
# Epoch: 028/050 | Batch 0100/0500 | Cost: 0.3903
# Epoch: 028/050 | Batch 0200/0500 | Cost: 0.9388
# Epoch: 028/050 | Batch 0300/0500 | Cost: 0.8260
# Epoch: 028/050 | Batch 0400/0500 | Cost: 0.4715
# Epoch: 028/050 | Batch 0500/0500 | Cost: 0.9745
# epoch 28, loss 0.7038, train acc 78.254%, top_1 test acc 68.450%, top_5 test acc 91.140%
# EPOCH:  29 learning rate:  0.01
# Epoch: 029/050 | Batch 0100/0500 | Cost: 0.8097
# Epoch: 029/050 | Batch 0200/0500 | Cost: 0.8463
# Epoch: 029/050 | Batch 0300/0500 | Cost: 0.4917
# Epoch: 029/050 | Batch 0400/0500 | Cost: 0.2663
# Epoch: 029/050 | Batch 0500/0500 | Cost: 1.3922
# epoch 29, loss 0.6785, train acc 79.082%, top_1 test acc 69.280%, top_5 test acc 90.980%
# EPOCH:  30 learning rate:  0.01
# Epoch: 030/050 | Batch 0100/0500 | Cost: 1.1021
# Epoch: 030/050 | Batch 0200/0500 | Cost: 0.6881
# Epoch: 030/050 | Batch 0300/0500 | Cost: 0.4187
# Epoch: 030/050 | Batch 0400/0500 | Cost: 0.9347
# Epoch: 030/050 | Batch 0500/0500 | Cost: 0.8079
# epoch 30, loss 0.6514, train acc 79.832%, top_1 test acc 69.810%, top_5 test acc 91.240%
# EPOCH:  31 learning rate:  0.001
# Epoch: 031/050 | Batch 0100/0500 | Cost: 0.2887
# Epoch: 031/050 | Batch 0200/0500 | Cost: 0.6188
# Epoch: 031/050 | Batch 0300/0500 | Cost: 0.2790
# ****************************************************************************************************
# Iter_num: 15300 Test_acc 92.07 Comm_round: 153000
# ****************************************************************************************************
# Epoch: 031/050 | Batch 0400/0500 | Cost: 0.8445
# Epoch: 031/050 | Batch 0500/0500 | Cost: 0.2098
# epoch 31, loss 0.5039, train acc 84.542%, top_1 test acc 72.250%, top_5 test acc 92.030%
# EPOCH:  32 learning rate:  0.001
# Epoch: 032/050 | Batch 0100/0500 | Cost: 0.5846
# Epoch: 032/050 | Batch 0200/0500 | Cost: 0.4023
# Epoch: 032/050 | Batch 0300/0500 | Cost: 1.7079
# Epoch: 032/050 | Batch 0400/0500 | Cost: 0.5843
# Epoch: 032/050 | Batch 0500/0500 | Cost: 0.5757
# epoch 32, loss 0.4264, train acc 87.174%, top_1 test acc 72.490%, top_5 test acc 92.400%
# EPOCH:  33 learning rate:  0.001
# Epoch: 033/050 | Batch 0100/0500 | Cost: 0.6473
# Epoch: 033/050 | Batch 0200/0500 | Cost: 0.5161
# Epoch: 033/050 | Batch 0300/0500 | Cost: 0.5383
# Epoch: 033/050 | Batch 0400/0500 | Cost: 0.2545
# Epoch: 033/050 | Batch 0500/0500 | Cost: 0.1818
# epoch 33, loss 0.4006, train acc 87.852%, top_1 test acc 72.840%, top_5 test acc 92.470%
# EPOCH:  34 learning rate:  0.001
# Epoch: 034/050 | Batch 0100/0500 | Cost: 0.2630
# Epoch: 034/050 | Batch 0200/0500 | Cost: 0.4116
# Epoch: 034/050 | Batch 0300/0500 | Cost: 0.3546
# Epoch: 034/050 | Batch 0400/0500 | Cost: 0.3319
# Epoch: 034/050 | Batch 0500/0500 | Cost: 0.4369
# epoch 34, loss 0.3880, train acc 88.312%, top_1 test acc 72.910%, top_5 test acc 92.380%
# EPOCH:  35 learning rate:  0.001
# Epoch: 035/050 | Batch 0100/0500 | Cost: 0.5129
# Epoch: 035/050 | Batch 0200/0500 | Cost: 0.6709
# Epoch: 035/050 | Batch 0300/0500 | Cost: 0.4773
# Epoch: 035/050 | Batch 0400/0500 | Cost: 0.3062
# Epoch: 035/050 | Batch 0500/0500 | Cost: 0.1517
# epoch 35, loss 0.3794, train acc 88.584%, top_1 test acc 72.820%, top_5 test acc 92.480%
# EPOCH:  36 learning rate:  0.001
# Epoch: 036/050 | Batch 0100/0500 | Cost: 0.2366
# Epoch: 036/050 | Batch 0200/0500 | Cost: 1.0349
# Epoch: 036/050 | Batch 0300/0500 | Cost: 0.3367
# Epoch: 036/050 | Batch 0400/0500 | Cost: 0.3761
# Epoch: 036/050 | Batch 0500/0500 | Cost: 1.1252
# epoch 36, loss 0.3614, train acc 89.082%, top_1 test acc 72.840%, top_5 test acc 92.450%
# EPOCH:  37 learning rate:  0.001
# Epoch: 037/050 | Batch 0100/0500 | Cost: 0.1839
# Epoch: 037/050 | Batch 0200/0500 | Cost: 0.1597
# Epoch: 037/050 | Batch 0300/0500 | Cost: 0.1834
# Epoch: 037/050 | Batch 0400/0500 | Cost: 0.2153
# Epoch: 037/050 | Batch 0500/0500 | Cost: 0.1647
# epoch 37, loss 0.3552, train acc 89.342%, top_1 test acc 72.780%, top_5 test acc 92.600%
# EPOCH:  38 learning rate:  0.001
# Epoch: 038/050 | Batch 0100/0500 | Cost: 0.4809
# Epoch: 038/050 | Batch 0200/0500 | Cost: 0.5363
# Epoch: 038/050 | Batch 0300/0500 | Cost: 0.2273
# Epoch: 038/050 | Batch 0400/0500 | Cost: 0.3713
# Epoch: 038/050 | Batch 0500/0500 | Cost: 0.9485
# epoch 38, loss 0.3423, train acc 89.732%, top_1 test acc 73.080%, top_5 test acc 92.450%
# EPOCH:  39 learning rate:  0.001
# Epoch: 039/050 | Batch 0100/0500 | Cost: 0.1617
# Epoch: 039/050 | Batch 0200/0500 | Cost: 0.5449
# Epoch: 039/050 | Batch 0300/0500 | Cost: 0.4255
# Epoch: 039/050 | Batch 0400/0500 | Cost: 0.5955
# Epoch: 039/050 | Batch 0500/0500 | Cost: 0.4017
# epoch 39, loss 0.3381, train acc 89.996%, top_1 test acc 73.070%, top_5 test acc 92.480%
# EPOCH:  40 learning rate:  0.001
# Epoch: 040/050 | Batch 0100/0500 | Cost: 0.7623
# Epoch: 040/050 | Batch 0200/0500 | Cost: 0.0653
# Epoch: 040/050 | Batch 0300/0500 | Cost: 0.5007
# Epoch: 040/050 | Batch 0400/0500 | Cost: 0.4123
# Epoch: 040/050 | Batch 0500/0500 | Cost: 0.5360
# epoch 40, loss 0.3293, train acc 90.230%, top_1 test acc 72.980%, top_5 test acc 92.570%
# EPOCH:  41 learning rate:  0.001
# Epoch: 041/050 | Batch 0100/0500 | Cost: 0.3310
# Epoch: 041/050 | Batch 0200/0500 | Cost: 0.7116
# Epoch: 041/050 | Batch 0300/0500 | Cost: 0.3227
# Epoch: 041/050 | Batch 0400/0500 | Cost: 0.3429
# Epoch: 041/050 | Batch 0500/0500 | Cost: 0.1620
# epoch 41, loss 0.3250, train acc 90.212%, top_1 test acc 73.040%, top_5 test acc 92.370%
# EPOCH:  42 learning rate:  0.001
# Epoch: 042/050 | Batch 0100/0500 | Cost: 0.1252
# Epoch: 042/050 | Batch 0200/0500 | Cost: 0.1560
# Epoch: 042/050 | Batch 0300/0500 | Cost: 0.4146
# Epoch: 042/050 | Batch 0400/0500 | Cost: 0.8197
# Epoch: 042/050 | Batch 0500/0500 | Cost: 0.0728
# epoch 42, loss 0.3198, train acc 90.534%, top_1 test acc 72.980%, top_5 test acc 92.580%
# EPOCH:  43 learning rate:  0.001
# Epoch: 043/050 | Batch 0100/0500 | Cost: 0.4312
# Epoch: 043/050 | Batch 0200/0500 | Cost: 0.2320
# Epoch: 043/050 | Batch 0300/0500 | Cost: 0.3884
# Epoch: 043/050 | Batch 0400/0500 | Cost: 0.2116
# Epoch: 043/050 | Batch 0500/0500 | Cost: 0.1961
# epoch 43, loss 0.3132, train acc 90.598%, top_1 test acc 73.120%, top_5 test acc 92.370%
# EPOCH:  44 learning rate:  0.001
# Epoch: 044/050 | Batch 0100/0500 | Cost: 0.3168
# Epoch: 044/050 | Batch 0200/0500 | Cost: 0.0474
# Epoch: 044/050 | Batch 0300/0500 | Cost: 0.2902
# Epoch: 044/050 | Batch 0400/0500 | Cost: 0.2649
# Epoch: 044/050 | Batch 0500/0500 | Cost: 0.5700
# epoch 44, loss 0.3074, train acc 90.894%, top_1 test acc 73.170%, top_5 test acc 92.350%
# EPOCH:  45 learning rate:  0.001
# Epoch: 045/050 | Batch 0100/0500 | Cost: 0.0898
# Epoch: 045/050 | Batch 0200/0500 | Cost: 0.2237
# Epoch: 045/050 | Batch 0300/0500 | Cost: 0.0846
# Epoch: 045/050 | Batch 0400/0500 | Cost: 0.6690
# Epoch: 045/050 | Batch 0500/0500 | Cost: 0.4090
# epoch 45, loss 0.3019, train acc 90.960%, top_1 test acc 72.620%, top_5 test acc 92.370%
# EPOCH:  46 learning rate:  0.001
# Epoch: 046/050 | Batch 0100/0500 | Cost: 0.2140
# Epoch: 046/050 | Batch 0200/0500 | Cost: 0.3756
# Epoch: 046/050 | Batch 0300/0500 | Cost: 0.4867
# Epoch: 046/050 | Batch 0400/0500 | Cost: 0.2839
# Epoch: 046/050 | Batch 0500/0500 | Cost: 0.3252
# epoch 46, loss 0.2935, train acc 91.092%, top_1 test acc 72.700%, top_5 test acc 92.450%
# EPOCH:  47 learning rate:  0.001
# Epoch: 047/050 | Batch 0100/0500 | Cost: 0.2352
# Epoch: 047/050 | Batch 0200/0500 | Cost: 0.4337
# Epoch: 047/050 | Batch 0300/0500 | Cost: 0.1546
# Epoch: 047/050 | Batch 0400/0500 | Cost: 0.4704
# Epoch: 047/050 | Batch 0500/0500 | Cost: 0.2964
# epoch 47, loss 0.2910, train acc 91.326%, top_1 test acc 72.990%, top_5 test acc 92.450%
# EPOCH:  48 learning rate:  0.001
# Epoch: 048/050 | Batch 0100/0500 | Cost: 0.4227
# Epoch: 048/050 | Batch 0200/0500 | Cost: 1.0915
# Epoch: 048/050 | Batch 0300/0500 | Cost: 0.5097
# Epoch: 048/050 | Batch 0400/0500 | Cost: 0.4027
# Epoch: 048/050 | Batch 0500/0500 | Cost: 0.1667
# epoch 48, loss 0.2827, train acc 91.458%, top_1 test acc 72.940%, top_5 test acc 92.720%
# EPOCH:  49 learning rate:  0.001
# Epoch: 049/050 | Batch 0100/0500 | Cost: 0.2627
# Epoch: 049/050 | Batch 0200/0500 | Cost: 0.1023
# Epoch: 049/050 | Batch 0300/0500 | Cost: 0.2258
# Epoch: 049/050 | Batch 0400/0500 | Cost: 0.3091
# Epoch: 049/050 | Batch 0500/0500 | Cost: 0.5978
# epoch 49, loss 0.2765, train acc 91.940%, top_1 test acc 73.000%, top_5 test acc 92.440%
# EPOCH:  50 learning rate:  0.001
# Epoch: 050/050 | Batch 0100/0500 | Cost: 0.2943
# Epoch: 050/050 | Batch 0200/0500 | Cost: 0.2662
# Epoch: 050/050 | Batch 0300/0500 | Cost: 0.3075
# Epoch: 050/050 | Batch 0400/0500 | Cost: 0.5226
# Epoch: 050/050 | Batch 0500/0500 | Cost: 0.2661
# epoch 50, loss 0.2774, train acc 91.696%, top_1 test acc 73.040%, top_5 test acc 92.400%
# Finished.

# %% [markdown]
# # SGD

# %%
print("Dis-SGD  lr:"+str(lr)+"--epoch:"+str(NUM_EPOCHS)+"--worker:"+str(NUM_WORKERS))
seed_torch(RANDOM_SEED)
model = resnet18()
model.to(DEVICE)
loss = nn.CrossEntropyLoss()  # 损失函数

# prepare data
dataset_name = 'cifar100'
train_loader_workers, test_loader = create_loaders(dataset_name, NUM_WORKERS, BATCH_SIZE)

NUM_PARAS = sum([1 for param in model.parameters()])
print("Number_parameter:", NUM_PARAS)
total_params = sum(p.numel() for p in model.parameters() if p.requires_grad)
print("Element_parameter:", total_params)

Loss_epoch = []
train_acc_epoch = []
test_acc_epoch = []
Loss_iter = []
train_acc_iter = []
test_acc_iter = []
iter_num = 0
flag_acc = False

for epoch in range(NUM_EPOCHS):
    train_l_sum, train_acc_sum, num = 0.0, 0.0, 0
    train_loader_iter = [iter(train_loader_workers[w]) for w in range(NUM_WORKERS)]
    iter_steps = len(train_loader_workers[0])

    # adjust learning_rate
    lr, _= adjust_lr(epoch)
    print("EPOCH: ", epoch + 1, "learning rate: ", lr)

    for batch_idx in range(iter_steps):
        model.train()
        grad_agg = [0 for col in range(NUM_PARAS)]
        for w_id in range(NUM_WORKERS):
            images, labels = next(train_loader_iter[w_id])
            images, labels = images.to(DEVICE), labels.to(DEVICE)
            y_hat = model(images)
            Loss = loss(y_hat, labels)
            Loss.backward()
            with torch.no_grad():
                p_id = 0
                for p in model.parameters():
                    grad_agg[p_id] += lr * p.grad.data.clone().detach()
                    p_id += 1
                    p.grad.zero_()
            train_l_sum += Loss.item()
            train_acc_sum += (y_hat.argmax(dim=1) == labels).sum().item()
            num += labels.shape[0]
        with torch.no_grad():
            p_id = 0
            for p in model.parameters():
                p.data.add_(grad_agg[p_id], alpha=-1)
                p_id += 1
                p.grad.zero_()
        # LOGGING
        if not (batch_idx + 1) % 100:
            print('Epoch: %03d/%03d | Batch %04d/%04d | Cost: %.4f'
                % (epoch + 1, NUM_EPOCHS, batch_idx + 1, len(train_loader_workers[0]), Loss.item()))
        iter_num += 1
        if not iter_num % 100:
            model.eval()
            with torch.no_grad():
                _, test_acc_it = evaluate_accuracy(model, test_loader, DEVICE)
                Loss_iter.append(train_l_sum / (num / BATCH_SIZE))
                train_acc_iter.append(train_acc_sum / num * 100)
                test_acc_iter.append(test_acc_it)
            if test_acc_it > 92.0 and not flag_acc:
                flag_acc = True
                print("*" * 100)
                print("Iter_num:", iter_num, "Test_acc", test_acc_it, "Comm_round:", iter_num * 10)  # 10 workers
                print("*" * 100)
    model.eval()
    with torch.no_grad():
        test_acc_1, test_acc_5 = evaluate_accuracy(model, test_loader, DEVICE)
        Loss_epoch.append(train_l_sum / (num / BATCH_SIZE))
        train_acc_epoch.append(train_acc_sum / num * 100)
        test_acc_epoch.append(test_acc_5)
    print('epoch %d, loss %.4f, train acc %.3f%%, top_1 test acc %.3f%%, top_5 test acc %.3f%%'
        % (epoch + 1, train_l_sum / (num / BATCH_SIZE), train_acc_sum / num * 100, test_acc_1, test_acc_5))

print('Finished.')

list_write = []
list_write.append(Loss_epoch)
list_write.append(train_acc_epoch)
list_write.append(test_acc_epoch)
name = ['Loss', 'train-acc', 'test-acc']
test = pd.DataFrame(index=name, data=list_write).T
test.to_csv("./result/"+"SGD-res-cifar100.csv", encoding='gbk')

list_write_iter = []
list_write_iter.append(Loss_iter)
list_write_iter.append(train_acc_iter)
list_write_iter.append(test_acc_iter)
name_iter = ['Loss', 'train-acc', 'test-acc']
test = pd.DataFrame(index=name_iter, data=list_write_iter).T
test.to_csv("./result/"+"SGD-res-cifar100-iter.csv", encoding='gbk')
# Out:
# Dis-SGD  lr:0.001--epoch:50--worker:10
# Files already downloaded and verified
# Files already downloaded and verified
# C:\Users\DxiaoG\AppData\Local\Temp\Mxt230\tmp\ipykernel_18272\1940885620.py:9: DeprecationWarning: `np.int` is a deprecated alias for the builtin `int`. To silence this warning, use `int` by itself. Doing this will not modify any behavior and is safe. When replacing `np.int`, you may wish to use e.g. `np.int64` or `np.int32` to specify the precision. If you wish to review your current use, check the release note link for additional information.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   a = np.int(np.floor(n / n_workers))
# Number_parameter: 62
# Element_parameter: 11220132
# EPOCH:  1 learning rate:  0.01
# Epoch: 001/050 | Batch 0100/0500 | Cost: 3.5330
# Epoch: 001/050 | Batch 0200/0500 | Cost: 3.7303
# Epoch: 001/050 | Batch 0300/0500 | Cost: 3.5812
# Epoch: 001/050 | Batch 0400/0500 | Cost: 3.7209
# Epoch: 001/050 | Batch 0500/0500 | Cost: 3.0867
# epoch 1, loss 3.8296, train acc 11.252%, top_1 test acc 19.820%, top_5 test acc 47.290%
# EPOCH:  2 learning rate:  0.01
# Epoch: 002/050 | Batch 0100/0500 | Cost: 3.9518
# Epoch: 002/050 | Batch 0200/0500 | Cost: 3.3709
# Epoch: 002/050 | Batch 0300/0500 | Cost: 3.4477
# Epoch: 002/050 | Batch 0400/0500 | Cost: 3.0580
# Epoch: 002/050 | Batch 0500/0500 | Cost: 3.9314
# epoch 2, loss 3.1530, train acc 22.204%, top_1 test acc 30.620%, top_5 test acc 62.150%
# EPOCH:  3 learning rate:  0.01
# Epoch: 003/050 | Batch 0100/0500 | Cost: 2.9875
# Epoch: 003/050 | Batch 0200/0500 | Cost: 3.9430
# Epoch: 003/050 | Batch 0300/0500 | Cost: 2.9098
# Epoch: 003/050 | Batch 0400/0500 | Cost: 2.4707
# Epoch: 003/050 | Batch 0500/0500 | Cost: 2.8034
# epoch 3, loss 2.7356, train acc 30.110%, top_1 test acc 37.010%, top_5 test acc 70.210%
# EPOCH:  4 learning rate:  0.01
# Epoch: 004/050 | Batch 0100/0500 | Cost: 1.8970
# Epoch: 004/050 | Batch 0200/0500 | Cost: 2.4198
# Epoch: 004/050 | Batch 0300/0500 | Cost: 2.0244
# Epoch: 004/050 | Batch 0400/0500 | Cost: 2.5540
# Epoch: 004/050 | Batch 0500/0500 | Cost: 2.5358
# epoch 4, loss 2.4211, train acc 36.908%, top_1 test acc 43.700%, top_5 test acc 75.350%
# EPOCH:  5 learning rate:  0.01
# Epoch: 005/050 | Batch 0100/0500 | Cost: 2.7129
# Epoch: 005/050 | Batch 0200/0500 | Cost: 2.3797
# Epoch: 005/050 | Batch 0300/0500 | Cost: 1.8786
# Epoch: 005/050 | Batch 0400/0500 | Cost: 2.3868
# Epoch: 005/050 | Batch 0500/0500 | Cost: 2.6196
# epoch 5, loss 2.1944, train acc 41.892%, top_1 test acc 46.840%, top_5 test acc 78.280%
# EPOCH:  6 learning rate:  0.01
# Epoch: 006/050 | Batch 0100/0500 | Cost: 2.1209
# Epoch: 006/050 | Batch 0200/0500 | Cost: 2.1965
# Epoch: 006/050 | Batch 0300/0500 | Cost: 2.2358
# Epoch: 006/050 | Batch 0400/0500 | Cost: 1.7538
# Epoch: 006/050 | Batch 0500/0500 | Cost: 3.0445
# epoch 6, loss 2.0340, train acc 45.284%, top_1 test acc 48.040%, top_5 test acc 77.860%
# EPOCH:  7 learning rate:  0.01
# Epoch: 007/050 | Batch 0100/0500 | Cost: 1.4803
# Epoch: 007/050 | Batch 0200/0500 | Cost: 2.1758
# Epoch: 007/050 | Batch 0300/0500 | Cost: 1.3559
# Epoch: 007/050 | Batch 0400/0500 | Cost: 1.7117
# Epoch: 007/050 | Batch 0500/0500 | Cost: 2.3244
# epoch 7, loss 1.8929, train acc 48.570%, top_1 test acc 52.220%, top_5 test acc 82.380%
# EPOCH:  8 learning rate:  0.01
# Epoch: 008/050 | Batch 0100/0500 | Cost: 1.5642
# Epoch: 008/050 | Batch 0200/0500 | Cost: 1.2704
# Epoch: 008/050 | Batch 0300/0500 | Cost: 0.9697
# Epoch: 008/050 | Batch 0400/0500 | Cost: 2.0942
# Epoch: 008/050 | Batch 0500/0500 | Cost: 2.1353
# epoch 8, loss 1.7646, train acc 51.510%, top_1 test acc 51.710%, top_5 test acc 81.610%
# EPOCH:  9 learning rate:  0.01
# Epoch: 009/050 | Batch 0100/0500 | Cost: 1.9961
# Epoch: 009/050 | Batch 0200/0500 | Cost: 1.2544
# Epoch: 009/050 | Batch 0300/0500 | Cost: 1.6322
# Epoch: 009/050 | Batch 0400/0500 | Cost: 1.7530
# Epoch: 009/050 | Batch 0500/0500 | Cost: 1.3822
# epoch 9, loss 1.6818, train acc 53.484%, top_1 test acc 55.470%, top_5 test acc 83.980%
# EPOCH:  10 learning rate:  0.01
# Epoch: 010/050 | Batch 0100/0500 | Cost: 1.3227
# Epoch: 010/050 | Batch 0200/0500 | Cost: 2.5055
# Epoch: 010/050 | Batch 0300/0500 | Cost: 1.5561
# Epoch: 010/050 | Batch 0400/0500 | Cost: 1.0241
# Epoch: 010/050 | Batch 0500/0500 | Cost: 2.1829
# epoch 10, loss 1.5843, train acc 55.886%, top_1 test acc 56.680%, top_5 test acc 84.530%
# EPOCH:  11 learning rate:  0.01
# Epoch: 011/050 | Batch 0100/0500 | Cost: 0.9495
# Epoch: 011/050 | Batch 0200/0500 | Cost: 1.2017
# Epoch: 011/050 | Batch 0300/0500 | Cost: 1.2009
# Epoch: 011/050 | Batch 0400/0500 | Cost: 1.4335
# Epoch: 011/050 | Batch 0500/0500 | Cost: 2.7538
# epoch 11, loss 1.5129, train acc 57.838%, top_1 test acc 58.250%, top_5 test acc 85.950%
# EPOCH:  12 learning rate:  0.01
# Epoch: 012/050 | Batch 0100/0500 | Cost: 1.9731
# Epoch: 012/050 | Batch 0200/0500 | Cost: 1.5973
# Epoch: 012/050 | Batch 0300/0500 | Cost: 1.1526
# Epoch: 012/050 | Batch 0400/0500 | Cost: 1.4468
# Epoch: 012/050 | Batch 0500/0500 | Cost: 0.6830
# epoch 12, loss 1.4351, train acc 59.648%, top_1 test acc 59.560%, top_5 test acc 86.360%
# EPOCH:  13 learning rate:  0.01
# Epoch: 013/050 | Batch 0100/0500 | Cost: 1.6638
# Epoch: 013/050 | Batch 0200/0500 | Cost: 1.4453
# Epoch: 013/050 | Batch 0300/0500 | Cost: 1.8986
# Epoch: 013/050 | Batch 0400/0500 | Cost: 1.7013
# Epoch: 013/050 | Batch 0500/0500 | Cost: 1.4671
# epoch 13, loss 1.3772, train acc 61.024%, top_1 test acc 60.800%, top_5 test acc 87.200%
# EPOCH:  14 learning rate:  0.01
# Epoch: 014/050 | Batch 0100/0500 | Cost: 1.1514
# Epoch: 014/050 | Batch 0200/0500 | Cost: 0.9630
# Epoch: 014/050 | Batch 0300/0500 | Cost: 0.8189
# Epoch: 014/050 | Batch 0400/0500 | Cost: 1.1328
# Epoch: 014/050 | Batch 0500/0500 | Cost: 1.6334
# epoch 14, loss 1.3152, train acc 62.286%, top_1 test acc 61.880%, top_5 test acc 87.600%
# EPOCH:  15 learning rate:  0.01
# Epoch: 015/050 | Batch 0100/0500 | Cost: 0.9998
# Epoch: 015/050 | Batch 0200/0500 | Cost: 0.9088
# Epoch: 015/050 | Batch 0300/0500 | Cost: 1.1598
# Epoch: 015/050 | Batch 0400/0500 | Cost: 1.3255
# Epoch: 015/050 | Batch 0500/0500 | Cost: 1.4751
# epoch 15, loss 1.2670, train acc 63.712%, top_1 test acc 62.240%, top_5 test acc 87.580%
# EPOCH:  16 learning rate:  0.01
# Epoch: 016/050 | Batch 0100/0500 | Cost: 0.6322
# Epoch: 016/050 | Batch 0200/0500 | Cost: 1.9708
# Epoch: 016/050 | Batch 0300/0500 | Cost: 1.2537
# Epoch: 016/050 | Batch 0400/0500 | Cost: 0.7139
# Epoch: 016/050 | Batch 0500/0500 | Cost: 1.8609
# epoch 16, loss 1.2141, train acc 65.254%, top_1 test acc 64.280%, top_5 test acc 88.710%
# EPOCH:  17 learning rate:  0.01
# Epoch: 017/050 | Batch 0100/0500 | Cost: 1.7223
# Epoch: 017/050 | Batch 0200/0500 | Cost: 1.3098
# Epoch: 017/050 | Batch 0300/0500 | Cost: 1.4175
# Epoch: 017/050 | Batch 0400/0500 | Cost: 1.9481
# Epoch: 017/050 | Batch 0500/0500 | Cost: 1.6626
# epoch 17, loss 1.1667, train acc 66.256%, top_1 test acc 63.310%, top_5 test acc 89.100%
# EPOCH:  18 learning rate:  0.01
# Epoch: 018/050 | Batch 0100/0500 | Cost: 0.4931
# Epoch: 018/050 | Batch 0200/0500 | Cost: 0.5832
# Epoch: 018/050 | Batch 0300/0500 | Cost: 1.5926
# Epoch: 018/050 | Batch 0400/0500 | Cost: 0.9670
# Epoch: 018/050 | Batch 0500/0500 | Cost: 0.9546
# epoch 18, loss 1.1181, train acc 67.530%, top_1 test acc 63.500%, top_5 test acc 88.980%
# EPOCH:  19 learning rate:  0.01
# Epoch: 019/050 | Batch 0100/0500 | Cost: 1.0330
# Epoch: 019/050 | Batch 0200/0500 | Cost: 1.2483
# Epoch: 019/050 | Batch 0300/0500 | Cost: 1.2470
# Epoch: 019/050 | Batch 0400/0500 | Cost: 0.9810
# Epoch: 019/050 | Batch 0500/0500 | Cost: 1.0751
# epoch 19, loss 1.0848, train acc 68.236%, top_1 test acc 65.730%, top_5 test acc 89.580%
# EPOCH:  20 learning rate:  0.01
# Epoch: 020/050 | Batch 0100/0500 | Cost: 1.6575
# Epoch: 020/050 | Batch 0200/0500 | Cost: 0.6092
# Epoch: 020/050 | Batch 0300/0500 | Cost: 1.5037
# Epoch: 020/050 | Batch 0400/0500 | Cost: 0.7684
# Epoch: 020/050 | Batch 0500/0500 | Cost: 0.9091
# epoch 20, loss 1.0335, train acc 69.724%, top_1 test acc 66.080%, top_5 test acc 90.270%
# EPOCH:  21 learning rate:  0.01
# Epoch: 021/050 | Batch 0100/0500 | Cost: 1.3141
# Epoch: 021/050 | Batch 0200/0500 | Cost: 0.5261
# Epoch: 021/050 | Batch 0300/0500 | Cost: 1.4824
# Epoch: 021/050 | Batch 0400/0500 | Cost: 0.7704
# Epoch: 021/050 | Batch 0500/0500 | Cost: 1.3106
# epoch 21, loss 1.0023, train acc 70.424%, top_1 test acc 66.620%, top_5 test acc 89.930%
# EPOCH:  22 learning rate:  0.01
# Epoch: 022/050 | Batch 0100/0500 | Cost: 0.8601
# Epoch: 022/050 | Batch 0200/0500 | Cost: 0.2887
# Epoch: 022/050 | Batch 0300/0500 | Cost: 0.7994
# Epoch: 022/050 | Batch 0400/0500 | Cost: 1.7264
# Epoch: 022/050 | Batch 0500/0500 | Cost: 1.3732
# epoch 22, loss 0.9602, train acc 71.650%, top_1 test acc 65.780%, top_5 test acc 89.850%
# EPOCH:  23 learning rate:  0.01
# Epoch: 023/050 | Batch 0100/0500 | Cost: 0.5307
# Epoch: 023/050 | Batch 0200/0500 | Cost: 0.4146
# Epoch: 023/050 | Batch 0300/0500 | Cost: 0.9879
# Epoch: 023/050 | Batch 0400/0500 | Cost: 1.2973
# Epoch: 023/050 | Batch 0500/0500 | Cost: 1.2110
# epoch 23, loss 0.9295, train acc 72.480%, top_1 test acc 66.640%, top_5 test acc 90.320%
# EPOCH:  24 learning rate:  0.01
# Epoch: 024/050 | Batch 0100/0500 | Cost: 0.5858
# Epoch: 024/050 | Batch 0200/0500 | Cost: 0.8064
# Epoch: 024/050 | Batch 0300/0500 | Cost: 0.5113
# Epoch: 024/050 | Batch 0400/0500 | Cost: 1.2275
# Epoch: 024/050 | Batch 0500/0500 | Cost: 0.4232
# epoch 24, loss 0.8918, train acc 73.340%, top_1 test acc 65.750%, top_5 test acc 89.600%
# EPOCH:  25 learning rate:  0.01
# Epoch: 025/050 | Batch 0100/0500 | Cost: 1.2349
# Epoch: 025/050 | Batch 0200/0500 | Cost: 0.8599
# Epoch: 025/050 | Batch 0300/0500 | Cost: 1.3480
# Epoch: 025/050 | Batch 0400/0500 | Cost: 1.0579
# Epoch: 025/050 | Batch 0500/0500 | Cost: 1.0404
# epoch 25, loss 0.8594, train acc 74.260%, top_1 test acc 68.120%, top_5 test acc 90.770%
# EPOCH:  26 learning rate:  0.01
# Epoch: 026/050 | Batch 0100/0500 | Cost: 1.8840
# Epoch: 026/050 | Batch 0200/0500 | Cost: 0.8259
# Epoch: 026/050 | Batch 0300/0500 | Cost: 0.4020
# Epoch: 026/050 | Batch 0400/0500 | Cost: 1.0699
# Epoch: 026/050 | Batch 0500/0500 | Cost: 0.9063
# epoch 26, loss 0.8344, train acc 74.838%, top_1 test acc 67.370%, top_5 test acc 89.990%
# EPOCH:  27 learning rate:  0.01
# Epoch: 027/050 | Batch 0100/0500 | Cost: 1.8389
# Epoch: 027/050 | Batch 0200/0500 | Cost: 0.4637
# Epoch: 027/050 | Batch 0300/0500 | Cost: 1.4023
# Epoch: 027/050 | Batch 0400/0500 | Cost: 0.7961
# Epoch: 027/050 | Batch 0500/0500 | Cost: 1.3792
# epoch 27, loss 0.8004, train acc 76.022%, top_1 test acc 67.280%, top_5 test acc 90.380%
# EPOCH:  28 learning rate:  0.01
# Epoch: 028/050 | Batch 0100/0500 | Cost: 0.7227
# Epoch: 028/050 | Batch 0200/0500 | Cost: 0.9287
# Epoch: 028/050 | Batch 0300/0500 | Cost: 0.7339
# Epoch: 028/050 | Batch 0400/0500 | Cost: 0.2744
# Epoch: 028/050 | Batch 0500/0500 | Cost: 0.9600
# epoch 28, loss 0.7746, train acc 76.332%, top_1 test acc 67.900%, top_5 test acc 91.280%
# EPOCH:  29 learning rate:  0.01
# Epoch: 029/050 | Batch 0100/0500 | Cost: 0.8652
# Epoch: 029/050 | Batch 0200/0500 | Cost: 1.0419
# Epoch: 029/050 | Batch 0300/0500 | Cost: 0.3299
# Epoch: 029/050 | Batch 0400/0500 | Cost: 0.4933
# Epoch: 029/050 | Batch 0500/0500 | Cost: 1.0493
# epoch 29, loss 0.7489, train acc 77.280%, top_1 test acc 68.170%, top_5 test acc 90.580%
# EPOCH:  30 learning rate:  0.01
# Epoch: 030/050 | Batch 0100/0500 | Cost: 1.3240
# Epoch: 030/050 | Batch 0200/0500 | Cost: 0.4850
# Epoch: 030/050 | Batch 0300/0500 | Cost: 0.4597
# Epoch: 030/050 | Batch 0400/0500 | Cost: 1.4796
# Epoch: 030/050 | Batch 0500/0500 | Cost: 0.3241
# epoch 30, loss 0.7211, train acc 77.976%, top_1 test acc 68.490%, top_5 test acc 90.790%
# EPOCH:  31 learning rate:  0.001
# Epoch: 031/050 | Batch 0100/0500 | Cost: 0.2434
# Epoch: 031/050 | Batch 0200/0500 | Cost: 0.3938
# ****************************************************************************************************
# Iter_num: 15200 Test_acc 92.03 Comm_round: 152000
# ****************************************************************************************************
# Epoch: 031/050 | Batch 0300/0500 | Cost: 0.2589
# Epoch: 031/050 | Batch 0400/0500 | Cost: 0.6000
# Epoch: 031/050 | Batch 0500/0500 | Cost: 0.2003
# epoch 31, loss 0.5343, train acc 83.880%, top_1 test acc 72.230%, top_5 test acc 92.160%
# EPOCH:  32 learning rate:  0.001
# Epoch: 032/050 | Batch 0100/0500 | Cost: 0.5028
# Epoch: 032/050 | Batch 0200/0500 | Cost: 0.6134
# Epoch: 032/050 | Batch 0300/0500 | Cost: 1.3161
# Epoch: 032/050 | Batch 0400/0500 | Cost: 0.4394
# Epoch: 032/050 | Batch 0500/0500 | Cost: 0.6320
# epoch 32, loss 0.4804, train acc 85.604%, top_1 test acc 72.330%, top_5 test acc 92.380%
# EPOCH:  33 learning rate:  0.001
# Epoch: 033/050 | Batch 0100/0500 | Cost: 1.3929
# Epoch: 033/050 | Batch 0200/0500 | Cost: 1.0199
# Epoch: 033/050 | Batch 0300/0500 | Cost: 0.3866
# Epoch: 033/050 | Batch 0400/0500 | Cost: 0.3088
# Epoch: 033/050 | Batch 0500/0500 | Cost: 0.1614
# epoch 33, loss 0.4593, train acc 86.212%, top_1 test acc 72.860%, top_5 test acc 92.510%
# EPOCH:  34 learning rate:  0.001
# Epoch: 034/050 | Batch 0100/0500 | Cost: 0.2862
# Epoch: 034/050 | Batch 0200/0500 | Cost: 0.3680
# Epoch: 034/050 | Batch 0300/0500 | Cost: 0.1976
# Epoch: 034/050 | Batch 0400/0500 | Cost: 0.2199
# Epoch: 034/050 | Batch 0500/0500 | Cost: 1.0566
# epoch 34, loss 0.4459, train acc 86.710%, top_1 test acc 72.790%, top_5 test acc 92.470%
# EPOCH:  35 learning rate:  0.001
# Epoch: 035/050 | Batch 0100/0500 | Cost: 0.6495
# Epoch: 035/050 | Batch 0200/0500 | Cost: 0.5664
# Epoch: 035/050 | Batch 0300/0500 | Cost: 0.5205
# Epoch: 035/050 | Batch 0400/0500 | Cost: 0.2545
# Epoch: 035/050 | Batch 0500/0500 | Cost: 0.1884
# epoch 35, loss 0.4308, train acc 87.136%, top_1 test acc 72.630%, top_5 test acc 92.770%
# EPOCH:  36 learning rate:  0.001
# Epoch: 036/050 | Batch 0100/0500 | Cost: 0.1705
# Epoch: 036/050 | Batch 0200/0500 | Cost: 1.0798
# Epoch: 036/050 | Batch 0300/0500 | Cost: 0.3342
# Epoch: 036/050 | Batch 0400/0500 | Cost: 0.4367
# Epoch: 036/050 | Batch 0500/0500 | Cost: 1.0312
# epoch 36, loss 0.4205, train acc 87.390%, top_1 test acc 72.890%, top_5 test acc 92.570%
# EPOCH:  37 learning rate:  0.001
# Epoch: 037/050 | Batch 0100/0500 | Cost: 0.1381
# Epoch: 037/050 | Batch 0200/0500 | Cost: 0.3833
# Epoch: 037/050 | Batch 0300/0500 | Cost: 0.1964
# Epoch: 037/050 | Batch 0400/0500 | Cost: 0.2328
# Epoch: 037/050 | Batch 0500/0500 | Cost: 0.0733
# epoch 37, loss 0.4091, train acc 87.586%, top_1 test acc 73.070%, top_5 test acc 92.730%
# EPOCH:  38 learning rate:  0.001
# Epoch: 038/050 | Batch 0100/0500 | Cost: 0.5469
# Epoch: 038/050 | Batch 0200/0500 | Cost: 1.3284
# Epoch: 038/050 | Batch 0300/0500 | Cost: 0.2632
# Epoch: 038/050 | Batch 0400/0500 | Cost: 0.2842
# Epoch: 038/050 | Batch 0500/0500 | Cost: 0.5735
# epoch 38, loss 0.4026, train acc 88.058%, top_1 test acc 73.100%, top_5 test acc 92.670%
# EPOCH:  39 learning rate:  0.001
# Epoch: 039/050 | Batch 0100/0500 | Cost: 0.1053
# Epoch: 039/050 | Batch 0200/0500 | Cost: 0.6954
# Epoch: 039/050 | Batch 0300/0500 | Cost: 0.3667
# Epoch: 039/050 | Batch 0400/0500 | Cost: 0.9588
# Epoch: 039/050 | Batch 0500/0500 | Cost: 0.4735
# epoch 39, loss 0.3936, train acc 88.200%, top_1 test acc 72.570%, top_5 test acc 92.520%
# EPOCH:  40 learning rate:  0.001
# Epoch: 040/050 | Batch 0100/0500 | Cost: 0.7291
# Epoch: 040/050 | Batch 0200/0500 | Cost: 0.0709
# Epoch: 040/050 | Batch 0300/0500 | Cost: 0.4570
# Epoch: 040/050 | Batch 0400/0500 | Cost: 0.5634
# Epoch: 040/050 | Batch 0500/0500 | Cost: 1.0791
# epoch 40, loss 0.3829, train acc 88.714%, top_1 test acc 72.770%, top_5 test acc 92.600%
# EPOCH:  41 learning rate:  0.001
# Epoch: 041/050 | Batch 0100/0500 | Cost: 0.3514
# Epoch: 041/050 | Batch 0200/0500 | Cost: 0.4175
# Epoch: 041/050 | Batch 0300/0500 | Cost: 0.7330
# Epoch: 041/050 | Batch 0400/0500 | Cost: 0.2382
# Epoch: 041/050 | Batch 0500/0500 | Cost: 0.5760
# epoch 41, loss 0.3806, train acc 88.576%, top_1 test acc 72.720%, top_5 test acc 92.600%
# EPOCH:  42 learning rate:  0.001
# Epoch: 042/050 | Batch 0100/0500 | Cost: 0.4577
# Epoch: 042/050 | Batch 0200/0500 | Cost: 0.2699
# Epoch: 042/050 | Batch 0300/0500 | Cost: 0.2615
# Epoch: 042/050 | Batch 0400/0500 | Cost: 0.6133
# Epoch: 042/050 | Batch 0500/0500 | Cost: 0.1807
# epoch 42, loss 0.3746, train acc 88.662%, top_1 test acc 72.650%, top_5 test acc 92.560%
# EPOCH:  43 learning rate:  0.001
# Epoch: 043/050 | Batch 0100/0500 | Cost: 0.5082
# Epoch: 043/050 | Batch 0200/0500 | Cost: 0.4463
# Epoch: 043/050 | Batch 0300/0500 | Cost: 0.5764
# Epoch: 043/050 | Batch 0400/0500 | Cost: 0.4031
# Epoch: 043/050 | Batch 0500/0500 | Cost: 0.1186
# epoch 43, loss 0.3647, train acc 89.240%, top_1 test acc 72.790%, top_5 test acc 92.560%
# EPOCH:  44 learning rate:  0.001
# Epoch: 044/050 | Batch 0100/0500 | Cost: 0.4262
# Epoch: 044/050 | Batch 0200/0500 | Cost: 0.1658
# Epoch: 044/050 | Batch 0300/0500 | Cost: 0.4454
# Epoch: 044/050 | Batch 0400/0500 | Cost: 0.5035
# Epoch: 044/050 | Batch 0500/0500 | Cost: 0.4423
# epoch 44, loss 0.3573, train acc 89.308%, top_1 test acc 72.940%, top_5 test acc 92.500%
# EPOCH:  45 learning rate:  0.001
# Epoch: 045/050 | Batch 0100/0500 | Cost: 0.3297
# Epoch: 045/050 | Batch 0200/0500 | Cost: 0.5359
# Epoch: 045/050 | Batch 0300/0500 | Cost: 0.0893
# Epoch: 045/050 | Batch 0400/0500 | Cost: 0.5958
# Epoch: 045/050 | Batch 0500/0500 | Cost: 0.3582
# epoch 45, loss 0.3569, train acc 89.220%, top_1 test acc 72.590%, top_5 test acc 92.490%
# EPOCH:  46 learning rate:  0.001
# Epoch: 046/050 | Batch 0100/0500 | Cost: 0.6632
# Epoch: 046/050 | Batch 0200/0500 | Cost: 0.5936
# Epoch: 046/050 | Batch 0300/0500 | Cost: 0.5356
# Epoch: 046/050 | Batch 0400/0500 | Cost: 0.4203
# Epoch: 046/050 | Batch 0500/0500 | Cost: 0.2465
# epoch 46, loss 0.3462, train acc 89.642%, top_1 test acc 72.840%, top_5 test acc 92.580%
# EPOCH:  47 learning rate:  0.001
# Epoch: 047/050 | Batch 0100/0500 | Cost: 0.4552
# Epoch: 047/050 | Batch 0200/0500 | Cost: 0.4040
# Epoch: 047/050 | Batch 0300/0500 | Cost: 0.1047
# Epoch: 047/050 | Batch 0400/0500 | Cost: 0.6851
# Epoch: 047/050 | Batch 0500/0500 | Cost: 0.8564
# epoch 47, loss 0.3411, train acc 89.756%, top_1 test acc 72.740%, top_5 test acc 92.660%
# EPOCH:  48 learning rate:  0.001
# Epoch: 048/050 | Batch 0100/0500 | Cost: 0.5314
# Epoch: 048/050 | Batch 0200/0500 | Cost: 1.0948
# Epoch: 048/050 | Batch 0300/0500 | Cost: 0.5895
# Epoch: 048/050 | Batch 0400/0500 | Cost: 0.2730
# Epoch: 048/050 | Batch 0500/0500 | Cost: 0.2213
# epoch 48, loss 0.3319, train acc 90.152%, top_1 test acc 72.770%, top_5 test acc 92.590%
# EPOCH:  49 learning rate:  0.001
# Epoch: 049/050 | Batch 0100/0500 | Cost: 0.5276
# Epoch: 049/050 | Batch 0200/0500 | Cost: 0.0795
# Epoch: 049/050 | Batch 0300/0500 | Cost: 0.1747
# Epoch: 049/050 | Batch 0400/0500 | Cost: 0.2595
# Epoch: 049/050 | Batch 0500/0500 | Cost: 0.6494
# epoch 49, loss 0.3245, train acc 90.336%, top_1 test acc 72.970%, top_5 test acc 92.380%
# EPOCH:  50 learning rate:  0.001
# Epoch: 050/050 | Batch 0100/0500 | Cost: 0.2259
# Epoch: 050/050 | Batch 0200/0500 | Cost: 0.1070
# Epoch: 050/050 | Batch 0300/0500 | Cost: 0.5315
# Epoch: 050/050 | Batch 0400/0500 | Cost: 0.5377
# Epoch: 050/050 | Batch 0500/0500 | Cost: 0.2727
# epoch 50, loss 0.3290, train acc 90.090%, top_1 test acc 72.960%, top_5 test acc 92.630%
# Finished.

# %% [markdown]
# ## Plotting

# %%
# Record once every 100 iterations, and 10 workers need to communicate in each iteration
original_num = 1000
print("original communication number:", original_num)

SASG_data = pd.read_csv("./result/"+"SASG-res-cifar100-iter.csv")
LASG_data = pd.read_csv("./result/"+"LASG-res-cifar100-iter.csv")
sparse_data = pd.read_csv("./result/"+"Sparse-res-cifar100-iter.csv")
sgd_data = pd.read_csv("./result/"+"SGD-res-cifar100-iter.csv")

SASG_skip = SASG_data['Skip'].values.tolist()
LASG_skip = LASG_data['Skip'].values.tolist()

comm_round_SASG = []
comm_round_LASG = []
comm_round_sparse = []
comm_round_dis = []
comm_bit_SASG = []
comm_bit_LASG = []
comm_bit_sparse = []
comm_bit_dis = []

comm_num_SASG, comm_num_LASG, comm_num_sparse, comm_num_dis = 0, 0, 0, 0
for i in range(len(SASG_skip)):
    comm_num_SASG += original_num
    comm_num_LASG += original_num
    comm_num_sparse += original_num
    comm_num_dis += original_num
    comm_round_SASG.append(comm_num_SASG - SASG_skip[i])
    comm_round_LASG.append(comm_num_LASG - LASG_skip[i])
    comm_round_sparse.append(comm_num_sparse)
    comm_round_dis.append(comm_num_dis)

font1 = {'weight': 'normal', 'size': 17}
font2 = {'weight': 'normal', 'size': 20}
plt.figure()
plt.rc('font', size=17)
plt.subplot(facecolor="whitesmoke")
plt.grid(axis="x", color='w', linestyle='-', which='major', linewidth=1.2)
plt.grid(axis="y", color='w', linestyle='-', which='both', linewidth=1.2)
plt.plot(comm_round_dis, sgd_data['test-acc'].values.tolist(), 'black', label='SGD', linewidth=2.5)
plt.plot(comm_round_sparse, sparse_data['test-acc'].values.tolist(), 'b', label='Sparse', linewidth=2.5)
plt.plot(comm_round_LASG, LASG_data['test-acc'].values.tolist(), 'g', label='LASG', linewidth=2.5)
plt.plot(comm_round_SASG, SASG_data['test-acc'].values.tolist(), 'r', label='SASG', linewidth=2.5)
ax = plt.gca()
xmajorLocator = MultipleLocator(50000)  # major
ax.xaxis.set_major_locator(xmajorLocator)
xminorLocator = MultipleLocator(25000)  # minor
ax.xaxis.set_minor_locator(xminorLocator)
ax.ticklabel_format(axis='x', style='scientific', scilimits=(0, 0))
plt.xlabel('Communication Round', font2)
plt.ylim(30, 95)
ymajorLocator = MultipleLocator(15)  # major
ax.yaxis.set_major_locator(ymajorLocator)
yminorLocator = MultipleLocator(15)  # minor
ax.yaxis.set_minor_locator(yminorLocator)
plt.ylabel('Test Accuracy', font2)
legend = plt.legend(prop=font1)
plt.subplots_adjust(left=0.13, right=0.95, bottom=0.15, top=0.95)
plt.savefig("./result/"+"test_res_cifar100.png", dpi=600)
plt.show()


plt.figure()
plt.rc('font', size=17)
plt.subplot(facecolor="whitesmoke")
plt.grid(axis="x", color='w', linestyle='-', which='major', linewidth=1.2)
plt.grid(axis="y", color='w', linestyle='-', which='major', linewidth=1.2)
plt.plot(comm_round_dis, sgd_data['Loss'].values.tolist(), 'black', label='SGD', linewidth=2.5)
plt.plot(comm_round_sparse, sparse_data['Loss'].values.tolist(), 'b', label='Sparse', linewidth=2.5)
plt.plot(comm_round_LASG, LASG_data['Loss'].values.tolist(), 'g', label='LASG', linewidth=2.5)
plt.plot(comm_round_SASG, SASG_data['Loss'].values.tolist(), 'r', label='SASG', linewidth=2.5)
ax = plt.gca()
xmajorLocator = MultipleLocator(50000)  # major
ax.xaxis.set_major_locator(xmajorLocator)
xminorLocator = MultipleLocator(25000)  # minor
ax.xaxis.set_minor_locator(xminorLocator)
ax.ticklabel_format(axis='x', style='scientific', scilimits=(0, 0))
plt.xlabel('Communication Round', font2)
plt.yscale('log')
plt.ylabel('Loss', font2)
plt.ylim(0.23, 4.99)
ax.set_yticks((0.3, 1, 3))
ax.set_yticklabels(['$3 x 10^{-1}$', '$10^{0}$', '$3 x 10^{0}$'], fontsize=17)
legend = plt.legend(prop=font1)
plt.subplots_adjust(left=0.16, right=0.95, bottom=0.15, top=0.95)
plt.savefig("./result/"+"loss_res_cifar100.png", dpi=600)
plt.show()
# Out:
# original communication number: 1000
